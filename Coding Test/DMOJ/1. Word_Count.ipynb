# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 입력 받을 때 input() 안에 아무 문장도 넣으면 안 되고, 출력할 때 print()로 해야 함

# %%
line1=input()
print(len(line1.split(' ')))
# Out:
# 5

# %%
line2=input()
print(line2.count(' ')+1)   # count(a)는 문장 내의 a의 갯수를 구해주는 것
# Out:
# 3
