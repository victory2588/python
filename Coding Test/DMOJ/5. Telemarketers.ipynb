# %% [markdown]
# ![image.png](attachment:image.png)

# %%
first=int(input())
second=int(input())
third=int(input())
last=int(input())

if 8<=first<=9 and second==third and 8<=last<=9:
    print('ignore')
else:
    print('answer')
# Out:
# answer

# %%
first=8
0<=first<=7
# Out:
# False
