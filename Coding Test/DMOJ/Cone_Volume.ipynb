# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 내 풀이

# %%
import math
radius=int(input())
height=int(input())
print(round((math.pi*radius*radius*height)/3,2))
# Out:
# 47.12

# %% [markdown]
# ### 답지 풀이

# %%
PI=3.141592653589793

radius=int(input())
height=int(input())

volume=round((PI * radius**2 * height)/3,2)

print(volume)
# Out:
# 47.12
