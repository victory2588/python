# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('C:\words.txt','r') as file:
    words=[]
    line=None
    while line !='':
        line=file.readline()
        words.append(line.strip('\n'))
for i in words:
    if list(i)==list(reversed(i)):
        print(i)
# Out:
# did
# noon
# refer
