# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_palindrome(word):
    if len(word)<2:
        return True
    if word[0] != word[-1]:
        return False
    return is_palindrome(word[1:-1])  # 해설 봄. 핵심은 어떻게 단어를 줄여서 다음 호출로 넘길까? 였는데, 그냥 슬라이싱으로 간단하게 해결...
    
print(is_palindrome('hello'))
print(is_palindrome('level'))
# Out:
# False
# True
