# %% [markdown]
# ![image.png](attachment:image.png)

# %%
files = input().split()
 
print(list(map(lambda x:'%03d%s'%(int(x[:x.find('.')]),x[x.find('.'):]),files)))  # 내가 한 것.. 더 깔끔하게 할 수 있을 것 같음
# Out:
# ['097.xlsx', '098.docx', '099.docx', '100.xlsx', '101.docx', '102.docx']

# %% [markdown]
# ![image.png](attachment:image.png)
