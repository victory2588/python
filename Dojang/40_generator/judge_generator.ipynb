# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def prime_number_generator(self,start,stop):
    self.start=start
    self.stop=stop
    
    for i in range(self.stop-self.start):
        for j in range(i):
            if i%j==0:
                


start, stop = map(int, input().split())
 
g = prime_number_generator(start, stop)
print(type(g))
for i in g:
    print(i, end=' ')
