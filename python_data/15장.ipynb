# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist=model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2933 - accuracy: 0.9141
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1460 - accuracy: 0.9564
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1111 - accuracy: 0.9669
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0897 - accuracy: 0.9712
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0756 - accuracy: 0.9760

# %%
test_loss, test_acc = model.evaluate(x_test, y_test,verbose=2)
print('test_acc: ', test_acc)
# Out:
# 313/313 - 0s - loss: 0.0827 - accuracy: 0.9719
# test_acc:  0.9718999862670898

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'])
plt.title("loss")
plt.subplot(1, 2, 2)

plt.title("accuracy")
plt.plot(hist.history['accuracy'], 'b-', label="training")
#plt.plot(model.history['val_accuracy'], 'r:', label="validation")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np         
import matplotlib.pylab as plt   
from skimage.data import coffee
from skimage.filters import sobel_h, sobel_v
from skimage.color import rgb2gray

# INPUT
image = coffee()
grey_image = rgb2gray(image)

# CONV
edge_h = sobel_h(grey_image)
edge_v = sobel_v(grey_image)

# %%
# ReLU
edge_h = np.where(edge_h < 0, 0, edge_h)
edge_v = np.where(edge_v < 0, 0, edge_v)
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,2)
plt.imshow(edge_h, cmap=plt.cm.gray)
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(edge_v, cmap=plt.cm.gray)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## 텐서플로 CNN 모델 만들기

# %%
from tensorflow.keras import datasets, layers, models
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# 픽셀 값을 0~1 사이로 정규화합니다.
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
 model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

hist=model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1521 - accuracy: 0.9536
# Epoch 2/5
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.0481 - accuracy: 0.9848
# Epoch 3/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0350 - accuracy: 0.9884
# Epoch 4/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0261 - accuracy: 0.9921
# Epoch 5/5
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0213 - accuracy: 0.9933

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('test_acc:',test_acc)
# Out:
# 313/313 - 1s - loss: 0.0244 - accuracy: 0.9924
# test_acc: 0.9923999905586243

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'])
plt.title("loss")
plt.subplot(1, 2, 2)

plt.title("accuracy")
plt.plot(hist.history['accuracy'], 'b-', label="training")
#plt.plot(model.history['val_accuracy'], 'r:', label="validation")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 텐서플로 Estimator

# %% [markdown]
# https://www.tensorflow.org/tutorials/estimator/premade?hl=ko

# %% [markdown]
# ### 1) 라이브러리 및 데이터 불러오기

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import pandas as pd

CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv
# 8192/2194 [================================================================================================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv
# 8192/573 [============================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %% [markdown]
# ### 2) 데이터 보기

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %% [markdown]
# ### 3) 데이터 분할

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')

train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %% [markdown]
# ### 4) 데이터 입력 기능 생성

# %%
def input_evaluation_set():
    features = {'SepalLength': np.array([6.4, 5.0]),
                'SepalWidth':  np.array([2.8, 2.3]),
                'PetalLength': np.array([5.6, 3.3]),
                'PetalWidth':  np.array([2.2, 1.0])}
    labels = np.array([2, 1])
    return features, labels

def input_fn(features, labels, training=True, batch_size=256):
    """An input function for training or evaluating"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# Feature columns describe how to use the input.
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))

# %% [markdown]
# ### 5)  DNN 모델 생성

# %%
# 30,10 유닛으로 구성된 2개 계층 DNN 생성 
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    
    hidden_units=[30, 10],
    # 3개 클래스다중분류 
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\konyang\\AppData\\Local\\Temp\\tmpbuj3nur1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# ### 6) DNN 모델훈련

# %%
classifier.train(input_fn=lambda: input_fn(train, train_y, training=True),steps=5000)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\optimizer_v2\adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.4578717, step = 0
# INFO:tensorflow:global_step/sec: 475.203
# INFO:tensorflow:loss = 1.0941249, step = 100 (0.211 sec)
# INFO:tensorflow:global_step/sec: 655.345
# INFO:tensorflow:loss = 1.0228015, step = 200 (0.154 sec)
# INFO:tensorflow:global_step/sec: 484.379
# INFO:tensorflow:loss = 0.9052676, step = 300 (0.205 sec)
# INFO:tensorflow:global_step/sec: 589.807
# INFO:tensorflow:loss = 0.8552094, step = 400 (0.170 sec)
# INFO:tensorflow:global_step/sec: 533.346
# INFO:tensorflow:loss = 0.8342327, step = 500 (0.187 sec)
# INFO:tensorflow:global_step/sec: 759.597
# INFO:tensorflow:loss = 0.8146132, step = 600 (0.132 sec)
# INFO:tensorflow:global_step/sec: 711.123
# INFO:tensorflow:loss = 0.7883688, step = 700 (0.141 sec)
# INFO:tensorflow:global_step/sec: 423.064
# INFO:tensorflow:loss = 0.7655424, step = 800 (0.239 sec)
# INFO:tensorflow:global_step/sec: 519.531
# INFO:tensorflow:loss = 0.73434496, step = 900 (0.189 sec)
# INFO:tensorflow:global_step/sec: 576.249
# INFO:tensorflow:loss = 0.72106004, step = 1000 (0.175 sec)
# INFO:tensorflow:global_step/sec: 721.351
# INFO:tensorflow:loss = 0.72214043, step = 1100 (0.138 sec)
# INFO:tensorflow:global_step/sec: 536.19
# INFO:tensorflow:loss = 0.69144666, step = 1200 (0.187 sec)
# INFO:tensorflow:global_step/sec: 506.401
# INFO:tensorflow:loss = 0.69236135, step = 1300 (0.197 sec)
# INFO:tensorflow:global_step/sec: 462.06
# INFO:tensorflow:loss = 0.6619719, step = 1400 (0.217 sec)
# INFO:tensorflow:global_step/sec: 642.745
# INFO:tensorflow:loss = 0.660375, step = 1500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 701.166
# INFO:tensorflow:loss = 0.64857566, step = 1600 (0.143 sec)
# INFO:tensorflow:global_step/sec: 808.618
# INFO:tensorflow:loss = 0.6323719, step = 1700 (0.124 sec)
# INFO:tensorflow:global_step/sec: 802.139
# INFO:tensorflow:loss = 0.616897, step = 1800 (0.125 sec)
# INFO:tensorflow:global_step/sec: 696.304
# INFO:tensorflow:loss = 0.6012305, step = 1900 (0.145 sec)
# INFO:tensorflow:global_step/sec: 759.604
# INFO:tensorflow:loss = 0.60053575, step = 2000 (0.132 sec)
# INFO:tensorflow:global_step/sec: 777.261
# INFO:tensorflow:loss = 0.59510815, step = 2100 (0.129 sec)
# INFO:tensorflow:global_step/sec: 759.604
# INFO:tensorflow:loss = 0.5905479, step = 2200 (0.131 sec)
# INFO:tensorflow:global_step/sec: 716.2
# INFO:tensorflow:loss = 0.595261, step = 2300 (0.141 sec)
# INFO:tensorflow:global_step/sec: 721.35
# INFO:tensorflow:loss = 0.5797998, step = 2400 (0.138 sec)
# INFO:tensorflow:global_step/sec: 783.338
# INFO:tensorflow:loss = 0.5559683, step = 2500 (0.129 sec)
# INFO:tensorflow:global_step/sec: 765.328
# INFO:tensorflow:loss = 0.562979, step = 2600 (0.130 sec)
# INFO:tensorflow:global_step/sec: 753.967
# INFO:tensorflow:loss = 0.5619445, step = 2700 (0.133 sec)
# INFO:tensorflow:global_step/sec: 759.571
# INFO:tensorflow:loss = 0.5544306, step = 2800 (0.133 sec)
# INFO:tensorflow:global_step/sec: 659.679
# INFO:tensorflow:loss = 0.55979955, step = 2900 (0.152 sec)
# INFO:tensorflow:global_step/sec: 701.142
# INFO:tensorflow:loss = 0.55675346, step = 3000 (0.142 sec)
# INFO:tensorflow:global_step/sec: 795.811
# INFO:tensorflow:loss = 0.5362557, step = 3100 (0.127 sec)
# INFO:tensorflow:global_step/sec: 726.577
# INFO:tensorflow:loss = 0.5606952, step = 3200 (0.138 sec)
# INFO:tensorflow:global_step/sec: 566.468
# INFO:tensorflow:loss = 0.5465013, step = 3300 (0.177 sec)
# INFO:tensorflow:global_step/sec: 527.737
# INFO:tensorflow:loss = 0.5446259, step = 3400 (0.189 sec)
# INFO:tensorflow:global_step/sec: 464.2
# INFO:tensorflow:loss = 0.5214876, step = 3500 (0.214 sec)
# INFO:tensorflow:global_step/sec: 759.606
# INFO:tensorflow:loss = 0.5335492, step = 3600 (0.133 sec)
# INFO:tensorflow:global_step/sec: 731.875
# INFO:tensorflow:loss = 0.52727413, step = 3700 (0.136 sec)
# INFO:tensorflow:global_step/sec: 759.608
# INFO:tensorflow:loss = 0.5262375, step = 3800 (0.132 sec)
# INFO:tensorflow:global_step/sec: 691.499
# INFO:tensorflow:loss = 0.5261446, step = 3900 (0.145 sec)
# INFO:tensorflow:global_step/sec: 789.509
# INFO:tensorflow:loss = 0.52784824, step = 4000 (0.127 sec)
# INFO:tensorflow:global_step/sec: 795.761
# INFO:tensorflow:loss = 0.5207393, step = 4100 (0.127 sec)
# INFO:tensorflow:global_step/sec: 716.207
# INFO:tensorflow:loss = 0.51553327, step = 4200 (0.139 sec)
# INFO:tensorflow:global_step/sec: 783.317
# INFO:tensorflow:loss = 0.50585324, step = 4300 (0.128 sec)
# INFO:tensorflow:global_step/sec: 742.742
# INFO:tensorflow:loss = 0.50726914, step = 4400 (0.136 sec)
# INFO:tensorflow:global_step/sec: 742.724
# INFO:tensorflow:loss = 0.49827054, step = 4500 (0.134 sec)
# INFO:tensorflow:global_step/sec: 748.263
# INFO:tensorflow:loss = 0.49556333, step = 4600 (0.135 sec)
# INFO:tensorflow:global_step/sec: 501.338
# INFO:tensorflow:loss = 0.51117766, step = 4700 (0.198 sec)
# INFO:tensorflow:global_step/sec: 560.154
# INFO:tensorflow:loss = 0.5108547, step = 4800 (0.179 sec)
# INFO:tensorflow:global_step/sec: 524.961
# INFO:tensorflow:loss = 0.504375, step = 4900 (0.191 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.5020517.

# %% [markdown]
# ### 7) 모델평가

# %%
eval_result = classifier.evaluate(input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-09-17T12:50:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.37303s
# INFO:tensorflow:Finished evaluation at 2020-09-17-12:50:11
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.53333336, average_loss = 0.6132309, global_step = 5000, loss = 0.6132309
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1\model.ckpt-5000
#
# Test set accuracy: 0.533

# %% [markdown]
# ### 8) 모델 배포를 통한 예측

# %%
# X값 입력으로 모델 예측 (변경해보세요)
# Prediction is "Setosa" (84.3%), expected "Setosa"
# Prediction is "Versicolor" (46.5%), expected "Versicolor"
# Prediction is "Virginica" (59.5%), expected "Virginica"

expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}

def input_fn(features, batch_size=256):
    """An input function for prediction."""
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

predictions = classifier.predict(
    input_fn=lambda: input_fn(predict_x))

for pred_dict, expec in zip(predictions, expected):
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%), expected "{}"'.format(
        SPECIES[class_id], 100 * probability, expec))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\konyang\AppData\Local\Temp\tmpbuj3nur1\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (84.1%), expected "Setosa"
# Prediction is "Virginica" (54.9%), expected "Versicolor"
# Prediction is "Virginica" (62.2%), expected "Virginica"
