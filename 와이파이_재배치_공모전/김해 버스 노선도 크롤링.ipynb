# %% [markdown]
# ## 김해시 시내버스 시간표 및 노선 정보 페이지에서 버스 번호 별 노선도를 크롤링
# - https://bus.koreacharts.com/city-bus/38070.html

# %% [markdown]
# ### 버스 노선 번호 및 URL 크롤링

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://bus.koreacharts.com/city-bus/38070.html'  # 실제 웹 페이지 URL로 변경해야 합니다.
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
else:
    print("웹 페이지에 접속할 수 없습니다.")


# ul 태그 내의 li 태그들을 찾음
bus_list_items = soup.select('ul.list-unstyled li')

# 결과를 저장할 딕셔너리 생성
bus_num = {}

# 각 li 태그에서 버스 번호와 URL을 추출하여 딕셔너리에 저장
for li in bus_list_items:
    bus_number = li.a.text.strip(' 번 버스')  # 버스 번호
    bus_url = li.a['href']  # 버스 URL
    bus_num[bus_number] = bus_url

del bus_num['시내버스 시간표']
del bus_num['시외버스터미널 시간표']
del bus_num['고속버스터미널 시간표']

# 결과 출력
for bus_number, bus_url in bus_num.items():
    print(f"버스 번호: {bus_number}, URL: {bus_url}")
# Out:
# 버스 번호: 1, URL: /city-bus/38070/GHB5.html
# 버스 번호: 1-1, URL: /city-bus/38070/GHB6.html
# 버스 번호: 10, URL: /city-bus/38070/GHB63.html
# 버스 번호: 100, URL: /city-bus/38070/GHB60.html
# 버스 번호: 11, URL: /city-bus/38070/GHB35.html
# 버스 번호: 11A, URL: /city-bus/38070/GHB75.html
# 버스 번호: 12, URL: /city-bus/38070/GHB48.html
# 버스 번호: 13, URL: /city-bus/38070/GHB39.html
# 버스 번호: 14-1, URL: /city-bus/38070/GHB54.html
# 버스 번호: 14-1A, URL: /city-bus/38070/GHB55.html
# 버스 번호: 140, URL: /city-bus/38070/GHB38.html
# 버스 번호: 15, URL: /city-bus/38070/GHB40.html
# 버스 번호: 15A, URL: /city-bus/38070/GHB70.html
# 버스 번호: 15B, URL: /city-bus/38070/GHB67.html
# 버스 번호: 16, URL: /city-bus/38070/GHB3.html
# 버스 번호: 16A, URL: /city-bus/38070/GHB84.html
# 버스 번호: 2, URL: /city-bus/38070/GHB9.html
# 버스 번호: 2-1, URL: /city-bus/38070/GHB71.html
# 버스 번호: 21, URL: /city-bus/38070/GHB12.html
# 버스 번호: 21-1, URL: /city-bus/38070/GHB47.html
# 버스 번호: 21-1A, URL: /city-bus/38070/GHB49.html
# 버스 번호: 21-1B, URL: /city-bus/38070/GHB33.html
# 버스 번호: 21-1C(막차), URL: /city-bus/38070/GHB59.html
# 버스 번호: 21A(막차), URL: /city-bus/38070/GHB90.html
# 버스 번호: 22, URL: /city-bus/38070/GHB61.html
# 버스 번호: 220, URL: /city-bus/38070/GHB2.html
# 버스 번호: 23, URL: /city-bus/38070/GHB14.html
# 버스 번호: 24, URL: /city-bus/38070/GHB10.html
# 버스 번호: 25, URL: /city-bus/38070/GHB13.html
# 버스 번호: 26, URL: /city-bus/38070/GHB16.html
# 버스 번호: 3, URL: /city-bus/38070/GHB45.html
# 버스 번호: 3-1, URL: /city-bus/38070/GHB44.html
# 버스 번호: 3-1A(막차), URL: /city-bus/38070/GHB89.html
# 버스 번호: 30, URL: /city-bus/38070/GHB17.html
# 버스 번호: 30-1, URL: /city-bus/38070/GHB11.html
# 버스 번호: 30-1A(막차), URL: /city-bus/38070/GHB66.html
# 버스 번호: 300, URL: /city-bus/38070/GHB50.html
# 버스 번호: 300A, URL: /city-bus/38070/GHB64.html
# 버스 번호: 31, URL: /city-bus/38070/GHB65.html
# 버스 번호: 31A, URL: /city-bus/38070/GHB73.html
# 버스 번호: 35, URL: /city-bus/38070/GHB18.html
# 버스 번호: 35A, URL: /city-bus/38070/GHB72.html
# 버스 번호: 3A, URL: /city-bus/38070/GHB78.html
# 버스 번호: 3B, URL: /city-bus/38070/GHB79.html
# 버스 번호: 4, URL: /city-bus/38070/GHB32.html
# 버스 번호: 44, URL: /city-bus/38070/GHB19.html
# 버스 번호: 44A, URL: /city-bus/38070/GHB31.html
# 버스 번호: 4A, URL: /city-bus/38070/GHB69.html
# 버스 번호: 5-1, URL: /city-bus/38070/GHB23.html
# 버스 번호: 56, URL: /city-bus/38070/GHB20.html
# 버스 번호: 57, URL: /city-bus/38070/GHB21.html
# 버스 번호: 57A, URL: /city-bus/38070/GHB62.html
# 버스 번호: 58, URL: /city-bus/38070/GHB7.html
# 버스 번호: 58-1, URL: /city-bus/38070/GHB22.html
# 버스 번호: 58A, URL: /city-bus/38070/GHB56.html
# 버스 번호: 59, URL: /city-bus/38070/GHB8.html
# 버스 번호: 59-1, URL: /city-bus/38070/GHB24.html
# 버스 번호: 59-1A, URL: /city-bus/38070/GHB46.html
# 버스 번호: 59-1B, URL: /city-bus/38070/GHB37.html
# 버스 번호: 59A, URL: /city-bus/38070/GHB57.html
# 버스 번호: 6, URL: /city-bus/38070/GHB34.html
# 버스 번호: 60, URL: /city-bus/38070/GHB25.html
# 버스 번호: 60A, URL: /city-bus/38070/GHB85.html
# 버스 번호: 60B, URL: /city-bus/38070/GHB87.html
# 버스 번호: 61, URL: /city-bus/38070/GHB26.html
# 버스 번호: 61A, URL: /city-bus/38070/GHB68.html
# 버스 번호: 61B, URL: /city-bus/38070/GHB86.html
# 버스 번호: 7, URL: /city-bus/38070/GHB27.html
# 버스 번호: 70, URL: /city-bus/38070/GHB58.html
# 버스 번호: 70A, URL: /city-bus/38070/GHB88.html
# 버스 번호: 72, URL: /city-bus/38070/GHB52.html
# 버스 번호: 72A, URL: /city-bus/38070/GHB80.html
# 버스 번호: 72B, URL: /city-bus/38070/GHB81.html
# 버스 번호: 72C, URL: /city-bus/38070/GHB77.html
# 버스 번호: 73, URL: /city-bus/38070/GHB53.html
# 버스 번호: 8, URL: /city-bus/38070/GHB1.html
# 버스 번호: 8-1, URL: /city-bus/38070/GHB4.html
# 버스 번호: 82, URL: /city-bus/38070/GHB28.html
# 버스 번호: 82A, URL: /city-bus/38070/GHB92.html
# 버스 번호: 83, URL: /city-bus/38070/GHB43.html
# 버스 번호: 9, URL: /city-bus/38070/GHB74.html
# 버스 번호: 97, URL: /city-bus/38070/GHB29.html
# 버스 번호: 97-1, URL: /city-bus/38070/GHB76.html
# 버스 번호: 98, URL: /city-bus/38070/GHB30.html
# 버스 번호: 대동공영, URL: /city-bus/38070/GHB36.html
# 버스 번호: 도시형1, URL: /city-bus/38070/GHB51.html
# 버스 번호: 도시형2, URL: /city-bus/38070/GHB82.html
# 버스 번호: 도시형3, URL: /city-bus/38070/GHB91.html
# 버스 번호: 상동공영1, URL: /city-bus/38070/GHB41.html
# 버스 번호: 상동공영2, URL: /city-bus/38070/GHB42.html

# %% [markdown]
# ### 버스 번호별 노선도 크롤링

# %%
bus_routes={}

for bus_number, bus_url in bus_num.items():
    url='https://bus.koreacharts.com/'+bus_url
    response = requests.get(url)
    bus_route=[]
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
    else:
        print("웹 페이지에 접속할 수 없습니다.")
    
    rows=soup.find_all("tr")

    for row in rows[1:]:
    # 각 <tr> 태그에서 <td> 태그를 찾아서 정보 추출
        columns = row.find_all('td')
        if len(columns) == 2:
            stop_name = columns[1].text.strip()
            bus_route.append(stop_name)
    bus_routes[bus_number]=bus_route

# %% [markdown]
# ### 만든 딕셔너리로 데이터프레임 만들기

# %%
bus_routes
# Out:
# {'1': ['삼계기점',
#   '공원묘지입구',
#   '삼계서희',
#   '삼계동원로얄듀크',
#   '가야대학교',
#   '현대가야아이파크',
#   '삼계축협',
#   '매정공원',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '부원역',
#   '김해시청',
#   '복음병원입구',
#   '복음병원',
#   '활천동',
#   '삼성초등학교',
#   '송림공원',
#   '어방2주공아파트',
#   '어방마을',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동문화의집',
#   '경남은행',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '어방2주공아파트',
#   '송림공원',
#   '삼성초등학교',
#   '활천동',
#   '복음병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '부원역',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '김해여고',
#   '청소년문화의집',
#   '광남백조아파트',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '매정공원',
#   '삼계축협',
#   '현대가야아이파크',
#   '가야대학교',
#   '두곡마을',
#   '삼계서희',
#   '공원묘지입구',
#   '삼계차고지'],
#  '1-1': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '부원역',
#   '김해시청',
#   '복음병원입구',
#   '복음병원',
#   '활천동',
#   '삼성초등학교',
#   '송림공원',
#   '어방2주공아파트',
#   '어방마을',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동사거리',
#   '안동공단',
#   '안동공단입구',
#   '김해대학역',
#   '경남은행',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '어방2주공아파트',
#   '송림공원',
#   '삼성초등학교',
#   '활천동',
#   '복음병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '부원역',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '김해여고',
#   '청소년문화의집',
#   '광남백조아파트',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '삼계푸르지오2차',
#   '장신대역',
#   '북부동행정복지센터',
#   '가야대역',
#   '삼계푸르지오1차',
#   '감분마을',
#   '신명마을',
#   '공원묘지입구',
#   '삼계차고지'],
#  '10': ['진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영단감농협',
#   '진영휴먼시아',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '진영중학교',
#   '진영자이',
#   '중흥S클래스',
#   '진영휴먼빌',
#   '주호',
#   '용성',
#   '본산',
#   '금봉마을입구',
#   '봉하삼거리',
#   '봉하입구',
#   '봉하',
#   '봉하입구',
#   '봉하삼거리',
#   '금봉마을입구',
#   '본산',
#   '용성',
#   '주호',
#   '진영휴먼빌',
#   '중흥S클래스',
#   '진영자이',
#   '진영코아루',
#   '진영중학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아',
#   '진영단감농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역'],
#  '100': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '무접',
#   '한국1차아파트',
#   '오복당서점',
#   '현대2차아파트',
#   '삼성아파트',
#   '연지우체국',
#   '홈플러스',
#   '학생체육관(연지공원)',
#   '연지공원',
#   '현대병원',
#   '구산육거리',
#   '롯데캐슬1단지',
#   '롯데캐슬',
#   '한덕아파트',
#   '활천고개',
#   '선거관리위원회',
#   '미소지움아파트',
#   'SK브로드밴드',
#   '자성공원',
#   '어방마을',
#   '인제대학교',
#   '인제공원',
#   '삼방교',
#   '삼방고등학교',
#   '동부스포츠센터',
#   '김해대학입구',
#   '김해대학교',
#   '삼방고등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '자성공원',
#   'SK브로드밴드',
#   '미소지움아파트',
#   '선거관리위원회',
#   '활천고개',
#   '한덕아파트',
#   '롯데캐슬',
#   '롯데캐슬1단지',
#   '구산육거리',
#   '현대병원',
#   '연지공원',
#   '학생체육관(연지공원)',
#   '휴앤락',
#   '대우아파트',
#   '삼성아파트',
#   '현대2차아파트',
#   '오복당서점',
#   '무접마을',
#   '무접',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '11': ['상룡',
#   '용담마을',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영농협',
#   '중구',
#   '삼성아파트',
#   '부곡',
#   '거성아파트',
#   '대근아파트',
#   '좌곤',
#   '금산초등학교',
#   '진영국토관리사무소',
#   '동산',
#   '사산',
#   '자여',
#   '외단계',
#   '서천',
#   '우동',
#   '오척',
#   '하계',
#   '대정마을',
#   '방동',
#   '보훈요양원',
#   '동산',
#   '진영국토관리사무소',
#   '좌곤육교',
#   '좌곤',
#   '대근아파트',
#   '거성아파트',
#   '부곡',
#   '삼성아파트',
#   '중구',
#   '진영농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '용담마을',
#   '상룡'],
#  '11A': ['상룡',
#   '효동마을',
#   '아랫양지',
#   '윗양지',
#   '용전',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영농협',
#   '중구',
#   '삼성아파트',
#   '부곡',
#   '거성아파트',
#   '대근아파트',
#   '좌곤',
#   '금산초등학교',
#   '진영국토관리사무소',
#   '동산',
#   '사산',
#   '자여',
#   '외단계',
#   '서천',
#   '우동',
#   '오척',
#   '하계',
#   '대정마을',
#   '방동',
#   '보훈요양원',
#   '동산',
#   '진영국토관리사무소',
#   '좌곤육교',
#   '좌곤',
#   '대근아파트',
#   '거성아파트',
#   '부곡',
#   '삼성아파트',
#   '중구',
#   '진영농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '용전',
#   '윗양지',
#   '아랫양지',
#   '효동마을',
#   '상룡'],
#  '12': ['진영공설운동장',
#   '진영공설운동장',
#   '진영병원',
#   '삼성아파트',
#   '부곡',
#   '신우희가로',
#   '중흥에코시티',
#   '진영이진캐스빌',
#   '진영자이',
#   '진영코아루',
#   '진영중학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아',
#   '진영단감농협',
#   '진영시외주차장',
#   '장복아파트',
#   '진영국민주택',
#   '원창시인의마을',
#   '금병공원',
#   '진우원',
#   '하계',
#   '대정마을',
#   '방동',
#   '보훈요양원',
#   '동산',
#   '진영국토관리사무소',
#   '금산초등학교',
#   '금산초등학교',
#   '진영국토관리사무소',
#   '동산',
#   '보훈요양원',
#   '방동',
#   '대정마을',
#   '하계',
#   '진우원',
#   '금병공원',
#   '원창시인의마을',
#   '진영국민주택',
#   '장복아파트',
#   '진영시외주차장',
#   '진영단감농협',
#   '진영휴먼시아',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '진영중학교',
#   '진영자이',
#   '진영이진캐스빌',
#   '중흥에코시티',
#   '신우희가로',
#   '부곡',
#   '삼성아파트',
#   '진영병원',
#   '진영공설운동장',
#   '진영공설운동장'],
#  '13': ['임시계류장',
#   '무계e-편한',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '진례백조아파트',
#   '진례중학교',
#   '돈담',
#   '강변농협',
#   '강변마을',
#   '담안',
#   '하평',
#   '진례역',
#   '대일화학',
#   '유니엠텍',
#   '동아HI',
#   '고창테크',
#   '고모교',
#   '고모마을',
#   '신모',
#   '빙그레삼거리',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레삼거리',
#   '신모',
#   '고모마을',
#   '고모교',
#   '고창테크',
#   '동아HI',
#   '유니엠텍',
#   '대일화학',
#   '진례역',
#   '하평',
#   '담안',
#   '강변마을',
#   '강변농협',
#   '돈담',
#   '진례중학교',
#   '진례백조아파트',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '무계e-편한',
#   '임시계류장'],
#  '14-1': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '한국1차아파트',
#   '오복당서점',
#   '현대2차아파트',
#   '삼성아파트',
#   '연지우체국',
#   '홈플러스',
#   '김해문화의전당',
#   '백조아파트후문',
#   '구산로타리',
#   '구산동우체국',
#   '구산동원아파트',
#   '한일유엔아이',
#   '노인복지회관',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분',
#   '망천2구',
#   '망천1구',
#   '신천',
#   '명동정수장',
#   '금음',
#   '인현',
#   '명동',
#   '새마을',
#   '소업마을',
#   '소업',
#   '신기',
#   '빙그레',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영휴먼시아 정문',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '금병초등학교',
#   '중흥S클래스',
#   '서재골공원',
#   '주천교',
#   '진영패션아울렛입구',
#   '진영패션아울렛입구',
#   '중포교',
#   '진영농협직판장',
#   '서재골공원',
#   '중흥S클래스',
#   '금병초등학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아 정문',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '소업',
#   '소업마을',
#   '새마을',
#   '명동',
#   '인현',
#   '금음',
#   '신천',
#   '망천1구',
#   '망천2구',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '노인복지회관',
#   '한일유엔아이',
#   '구산동원아파트',
#   '구산동우체국',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '휴앤락',
#   '대우아파트',
#   '삼성아파트',
#   '현대2차아파트',
#   '오복당서점',
#   '무접마을',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '외동차고지(종점)'],
#  '14-1A': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '한국1차아파트',
#   '오복당서점',
#   '현대2차아파트',
#   '삼성아파트',
#   '연지우체국',
#   '홈플러스',
#   '김해문화의전당',
#   '백조아파트후문',
#   '구산로타리',
#   '구산동우체국',
#   '구산동원아파트',
#   '한일유엔아이',
#   '노인복지회관',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분',
#   '망천2구',
#   '망천1구',
#   '신천',
#   '명동정수장',
#   '금음',
#   '인현',
#   '명동',
#   '새마을',
#   '소업마을',
#   '소업',
#   '신기',
#   '빙그레',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영휴먼시아 정문',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '금병초등학교',
#   '중흥S클래스',
#   '진영자이',
#   '진영중앙초등학교',
#   '서재골공원',
#   '중흥S클래스',
#   '금병초등학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아 정문',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '소업',
#   '소업마을',
#   '새마을',
#   '명동',
#   '인현',
#   '금음',
#   '신천',
#   '망천1구',
#   '망천2구',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '노인복지회관',
#   '한일유엔아이',
#   '구산동원아파트',
#   '구산동우체국',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '휴앤락',
#   '대우아파트',
#   '삼성아파트',
#   '현대2차아파트',
#   '오복당서점',
#   '무접마을',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '외동차고지(종점)'],
#  '140': ['김해여객터미널(종점)',
#   '무접',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '김해여고',
#   '청소년문화의집',
#   '광남백조아파트',
#   '구산동우체국',
#   '구산동원아파트',
#   '한일유엔아이',
#   '노인복지회관',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분',
#   '망천2구',
#   '망천1구',
#   '신천',
#   '명동정수장',
#   '금음',
#   '인현',
#   '명동',
#   '새마을',
#   '소업마을',
#   '소업',
#   '신기',
#   '빙그레',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영농협',
#   '중구',
#   '삼성아파트',
#   '부곡',
#   '거성아파트',
#   '대근아파트',
#   '좌곤',
#   '좌곤육교',
#   '무성마을입구',
#   '자여사거리',
#   '동읍지구대',
#   '용잠삼거리',
#   '동읍덕산마을',
#   '용전.남산마을입구',
#   '용암',
#   '용강검문소',
#   '도계동만남의광장',
#   '금호온천',
#   '소답동',
#   '의창동환승센터',
#   '윤병원',
#   '태광주유소',
#   '서상삼거리',
#   '창원역',
#   '한국전력',
#   '마산시외버스터미널',
#   '한국전력',
#   '창원역',
#   '서상삼거리',
#   '참사랑병원앞',
#   '윤병원',
#   '의창동환승센터',
#   '소답동',
#   '도계동만남의광장',
#   '용강검문소',
#   '용암',
#   '용전입구',
#   '동읍덕산마을',
#   '용잠삼거리',
#   '동읍지구대',
#   '자여사거리',
#   '무성마을입구',
#   '좌곤육교',
#   '좌곤',
#   '대근아파트',
#   '거성아파트',
#   '부곡',
#   '삼성아파트',
#   '중구',
#   '진영농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '소업',
#   '소업마을',
#   '새마을',
#   '명동',
#   '인현',
#   '금음',
#   '신천',
#   '망천1구',
#   '망천2구',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '노인복지회관',
#   '한일유엔아이',
#   '구산동원아파트',
#   '구산동우체국',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해여객터미널(종점)'],
#  '15': ['진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레삼거리',
#   '신모',
#   '고모마을',
#   '고모',
#   '상우',
#   '서창',
#   '계명티아이',
#   '유니테크',
#   '개동',
#   '상평',
#   '담안',
#   '담안마을',
#   '오룡',
#   '당리',
#   '학성',
#   '강변농협',
#   '돈담',
#   '진례중학교',
#   '진례백조아파트',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '무계e-편한',
#   '임시계류장',
#   '무계e-편한',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '진례백조아파트',
#   '진례중학교',
#   '돈담',
#   '강변농협',
#   '학성',
#   '당리',
#   '오룡',
#   '담안마을',
#   '담안',
#   '상평',
#   '개동',
#   '유니테크',
#   '계명티아이',
#   '서창',
#   '상우',
#   '고모',
#   '고모마을',
#   '신모',
#   '빙그레삼거리',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장'],
#  '15A': ['진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '소업',
#   '소업마을',
#   '퇴은마을',
#   '신기마을',
#   '신기',
#   '빙그레삼거리',
#   '신모',
#   '고모마을',
#   '고모',
#   '상우',
#   '서창',
#   '계명티아이',
#   '유니테크',
#   '개동',
#   '상평',
#   '담안',
#   '담안마을',
#   '오룡',
#   '당리',
#   '학성',
#   '강변농협',
#   '돈담',
#   '진례중학교',
#   '진례백조아파트',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '무계e-편한',
#   '임시계류장',
#   '무계e-편한',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '진례백조아파트',
#   '진례중학교',
#   '돈담',
#   '강변농협',
#   '학성',
#   '당리',
#   '오룡',
#   '담안마을',
#   '담안',
#   '상평',
#   '개동',
#   '유니테크',
#   '계명티아이',
#   '서창',
#   '상우',
#   '고모',
#   '고모마을',
#   '신모',
#   '빙그레삼거리',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장'],
#  '15B': ['진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '설창',
#   '진영역(김해행)',
#   '빙그레삼거리',
#   '신모',
#   '고모마을',
#   '고모',
#   '상우',
#   '서창',
#   '계명티아이',
#   '유니테크',
#   '개동',
#   '상평',
#   '담안',
#   '담안마을',
#   '오룡',
#   '당리',
#   '학성',
#   '강변농협',
#   '돈담',
#   '진례중학교',
#   '진례백조아파트',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '무계e-편한',
#   '임시계류장',
#   '무계e-편한',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '진례백조아파트',
#   '진례중학교',
#   '돈담',
#   '강변농협',
#   '학성',
#   '당리',
#   '오룡',
#   '담안마을',
#   '담안',
#   '상평',
#   '개동',
#   '유니테크',
#   '계명티아이',
#   '서창',
#   '상우',
#   '고모',
#   '고모마을',
#   '신모',
#   '빙그레',
#   '신기',
#   '소업',
#   '소업마을',
#   '퇴은마을',
#   '신기마을',
#   '신기',
#   '빙그레',
#   '진영역',
#   '설창',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장'],
#  '16': ['중흥에코시티후문',
#   '중흥에코시티정문',
#   '진영이진캐스빌',
#   '진영중앙초등학교',
#   '진영기업은행',
#   '진영역사공원',
#   '진영농협',
#   '진영시외주차장',
#   '진영휴먼시아 정문',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '금병초등학교',
#   '진영휴먼빌',
#   '주호',
#   '주호',
#   '진영휴먼빌',
#   '금병초등학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아 정문',
#   '진영시외주차장',
#   '진영농협',
#   '진영역사공원',
#   '진영자이',
#   '진영중앙초등학교',
#   '진영이진캐스빌',
#   '중흥에코시티정문',
#   '중흥에코시티후문'],
#  '16A': ['중흥에코시티후문',
#   '중흥에코시티정문',
#   '진영이진캐스빌',
#   '진영중앙초등학교',
#   '진영기업은행',
#   '진영역사공원',
#   '진영농협',
#   '진영시외주차장',
#   '진영휴먼시아 정문',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '금병초등학교',
#   '진영휴먼빌',
#   '주호',
#   '용성',
#   '본산마을입구',
#   '본산마을',
#   '주호교',
#   '주호마을회관',
#   '주호',
#   '진영휴먼빌',
#   '금병초등학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아 정문',
#   '진영시외주차장',
#   '진영농협',
#   '진영역사공원',
#   '진영자이',
#   '진영중앙초등학교',
#   '진영이진캐스빌',
#   '중흥에코시티정문',
#   '중흥에코시티후문'],
#  '2': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '한국1차아파트',
#   '가야고',
#   '임호초등학교',
#   '덕산아파트',
#   '대동아파트',
#   '뜨란채아파트',
#   '내외동행정복지센터',
#   '현대2차아파트',
#   '삼성아파트',
#   '현대1차아파트',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '부원역',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '자성공원',
#   '신어볼링장',
#   '어방동',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '부원역',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '현대1차아파트',
#   '삼성아파트',
#   '가야고',
#   '임호중학교',
#   '내외동행정복지센터',
#   '뜨란채아파트',
#   '한국2차아파트',
#   '한국1차아파트',
#   '동일아파트',
#   '이마트 신세계백화점',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '2-1': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '한국1차아파트',
#   '가야고',
#   '임호초등학교',
#   '덕산아파트',
#   '대동아파트',
#   '뜨란채아파트',
#   '내외동행정복지센터',
#   '현대2차아파트',
#   '삼성아파트',
#   '현대1차아파트',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '안동공단입구',
#   '안동공단',
#   '대아한일아파트',
#   '계내마을',
#   '칠암문화센터',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '자성공원',
#   '신어볼링장',
#   '어방동',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '현대1차아파트',
#   '삼성아파트',
#   '가야고',
#   '임호중학교',
#   '내외동행정복지센터',
#   '뜨란채아파트',
#   '한국2차아파트',
#   '한국1차아파트',
#   '동일아파트',
#   '이마트 신세계백화점',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '21': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '장유석봉마을',
#   '월산초등학교',
#   '대동피렌체앙코르',
#   '삼문고등학교',
#   '능동삼거리',
#   '장유도서관',
#   '갑오마을',
#   '부영8차아파트',
#   '계동초등학교',
#   '덕정사거리',
#   '팔판마을1단지',
#   '대우푸르지오6차',
#   '신안교',
#   '팔판마을',
#   '관동중학교',
#   '덕정초등학교',
#   '공방마을',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠',
#   '서부문화센터',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저힐스테이트',
#   '율산초등학교',
#   '율하시티프라디움',
#   '원메이저푸르지오',
#   '모산초등학교',
#   '율하자이',
#   '율하2지구상가',
#   '서부문화센터',
#   '중앙하이츠',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '세영리첼아파트',
#   '덕정초등학교',
#   '관동중학교',
#   '팔판마을',
#   '신안교',
#   '대우푸르지오6차',
#   '팔판마을1단지',
#   '덕정사거리',
#   '계동초등학교',
#   '부영8차아파트',
#   '갑오마을',
#   '장유도서관',
#   '능동삼거리',
#   '삼문고등학교',
#   '대동피렌체앙코르',
#   '월산초등학교',
#   '장유석봉마을',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '21-1': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '선천교차로',
#   '선천마을',
#   '센텀두산위브',
#   '주촌서희',
#   '조만강',
#   '주촌초등학교',
#   '선천마을',
#   '선천산책로',
#   '주촌농협',
#   '지혜의바다',
#   '내삼공단입구',
#   '자현',
#   '부경축산',
#   '후포',
#   '대한가스',
#   '하손',
#   '유하',
#   '유하마을회관',
#   '외덕',
#   '장유초등학교',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '무계교',
#   '쌍용예가',
#   '삼문마을',
#   '장유푸르지오8차',
#   '메가병원',
#   '대청2교',
#   '대청중학교',
#   '대청초등학교',
#   '삼문마을',
#   '쌍용예가',
#   '무계교',
#   '장유농협',
#   '대동1단지',
#   '외덕',
#   '유하마을회관',
#   '유하',
#   '하손',
#   '대한가스',
#   '후포',
#   '부경축산',
#   '자현',
#   '내삼공단입구',
#   '지혜의바다',
#   '주촌농협',
#   '선천산책로',
#   '선천마을',
#   '주촌초등학교',
#   '조만강',
#   '주촌서희',
#   '센텀두산위브',
#   '선천마을',
#   '선천교차로',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '21-1A': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '선천교차로',
#   '선천마을',
#   '센텀두산위브',
#   '주촌서희',
#   '조만강',
#   '주촌초등학교',
#   '선천마을',
#   '선천산책로',
#   '주촌농협',
#   '지혜의바다',
#   '내삼공단입구',
#   '자현',
#   '부경축산',
#   '후포',
#   '대한가스',
#   '하손',
#   '유하',
#   '유하마을회관',
#   '외덕',
#   '장유초등학교',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '무계교',
#   '쌍용예가',
#   '삼문마을',
#   '장유푸르지오8차',
#   '메가병원',
#   '대청2교',
#   '대청중학교',
#   '대청초등학교',
#   '삼문마을',
#   '쌍용예가',
#   '무계교',
#   '장유농협',
#   '대동1단지',
#   '외덕',
#   '유하마을회관',
#   '유하',
#   '하손',
#   '대한가스',
#   '후포',
#   '부경축산',
#   '자현',
#   '내삼공단입구',
#   '내삼마을',
#   '지혜의바다',
#   '주촌농협',
#   '선천산책로',
#   '선천마을',
#   '주촌초등학교',
#   '조만강',
#   '주촌서희',
#   '센텀두산위브',
#   '선천마을',
#   '선천교차로',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '21-1B': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '선천교차로',
#   '선천마을',
#   '센텀두산위브',
#   '주촌서희',
#   '조만강',
#   '주촌초등학교',
#   '선천마을',
#   '선천산책로',
#   '주촌농협',
#   '지혜의바다',
#   '내삼마을',
#   '내삼공단입구',
#   '자현',
#   '부경축산',
#   '후포',
#   '대한가스',
#   '하손',
#   '유하',
#   '유하마을회관',
#   '외덕',
#   '장유초등학교',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '무계교',
#   '쌍용예가',
#   '삼문마을',
#   '장유푸르지오8차',
#   '메가병원',
#   '대청2교',
#   '대청중학교',
#   '대청초등학교',
#   '삼문마을',
#   '쌍용예가',
#   '무계교',
#   '장유농협',
#   '대동1단지',
#   '외덕',
#   '유하마을회관',
#   '유하',
#   '하손',
#   '대한가스',
#   '후포',
#   '부경축산',
#   '자현',
#   '내삼공단입구',
#   '지혜의바다',
#   '주촌농협',
#   '선천산책로',
#   '선천마을',
#   '주촌초등학교',
#   '조만강',
#   '주촌서희',
#   '센텀두산위브',
#   '선천마을',
#   '선천교차로',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '21-1C(막차)': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '선천교차로',
#   '선천마을',
#   '센텀두산위브',
#   '주촌서희',
#   '조만강',
#   '주촌초등학교',
#   '선천마을',
#   '선천산책로',
#   '주촌농협',
#   '지혜의바다',
#   '내삼공단입구',
#   '자현',
#   '부경축산',
#   '후포',
#   '대한가스',
#   '하손',
#   '유하',
#   '유하마을회관',
#   '외덕',
#   '장유초등학교',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '무계교',
#   '쌍용예가',
#   '삼문마을',
#   '장유푸르지오8차',
#   '메가병원'],
#  '21A(막차)': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '장유석봉마을',
#   '월산초등학교',
#   '대동피렌체앙코르',
#   '삼문고등학교',
#   '능동삼거리',
#   '장유도서관',
#   '갑오마을',
#   '부영8차아파트',
#   '계동초등학교',
#   '덕정사거리',
#   '팔판마을1단지',
#   '대우푸르지오6차',
#   '신안교',
#   '팔판마을',
#   '관동중학교',
#   '덕정초등학교',
#   '공방마을',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠',
#   '서부문화센터',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저힐스테이트',
#   '율산초등학교',
#   '율하시티프라디움'],
#  '22': ['임시계류장',
#   '무계e-편한',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '월산3단지',
#   '월산4단지',
#   '한림리츠빌',
#   '능동삼거리',
#   '장유도서관',
#   '갑오마을',
#   '대청고등학교',
#   '대청초등학교',
#   '삼문마을',
#   '쌍용예가',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '롯데아울렛',
#   '롯데워터파크',
#   '율하2지구입구',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저푸르지오',
#   '율하시티프라디움',
#   '율산초등학교',
#   '원메이저힐스테이트',
#   '율하자이',
#   '율하2지구상가',
#   '율하2지구입구',
#   '롯데워터파크',
#   '롯데아울렛',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '쌍용예가',
#   '삼문마을',
#   '대청초등학교',
#   '대청고등학교',
#   '갑오마을',
#   '장유도서관',
#   '능동삼거리',
#   '한림리츠빌',
#   '월산4단지',
#   '월산3단지',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '무계e-편한',
#   '임시계류장'],
#  '220': ['풍유동차고지',
#   '풍유동차고지앞',
#   '농소교',
#   '한발매스테크',
#   '의생명센터',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '농수산물유통센터입구',
#   '롯데아울렛',
#   '롯데워터파크',
#   '용산마을',
#   '한림풀에버',
#   '관동초등학교',
#   '중앙하이츠후문',
#   '중앙하이츠',
#   '서부문화센터',
#   '율하2지구입구',
#   '장유모산마을',
#   '응달',
#   '응달마을',
#   '태정',
#   '용곡',
#   '수가마을',
#   '가동마을',
#   '가동마을입구',
#   '조만포',
#   '사구',
#   '녹산동행정복지센터',
#   '렛츠런파크입구',
#   '세산삼거리',
#   '생곡마을',
#   '용적사입구',
#   '가리새마을',
#   '성산',
#   '순아동',
#   '강서경찰서',
#   '사취등',
#   '경일고등학교입구',
#   '을숙도문화회관',
#   '하단역',
#   '하단역',
#   '을숙도(문화회관)',
#   '경일고등학교입구',
#   '사취등',
#   '강서경찰서',
#   '순아동',
#   '성산',
#   '가리새마을',
#   '용적사입구',
#   '생곡마을',
#   '세산삼거리',
#   '렛츠런파크입구',
#   '녹산동행정복지센터',
#   '사구',
#   '조만포',
#   '가동마을입구',
#   '가동마을',
#   '수가마을',
#   '용곡',
#   '태정',
#   '응달마을',
#   '응달',
#   '장유모산마을',
#   '율하2지구입구',
#   '서부문화센터',
#   '중앙하이츠',
#   '중앙하이츠후문',
#   '관동초등학교',
#   '한림풀에버',
#   '용산마을',
#   '롯데워터파크',
#   '롯데아울렛',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '부산은행주촌공단',
#   '중소기업비지니스센터',
#   '한발매스테크',
#   '농소교',
#   '풍유동차고지'],
#  '23': ['임시계류장',
#   '무계e-편한',
#   '내덕중학교',
#   '외덕',
#   '장유초등학교',
#   '장유석봉마을',
#   '장유고등학교',
#   '대동2단지',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '용산',
#   '용산마을',
#   '한림풀에버',
#   '죽림',
#   '화촌',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율하초등학교',
#   '농협수남지점',
#   '동원로얄듀크1차',
#   '율현주공',
#   '율하e-편한',
#   '서부문화센터',
#   '율하파출소(남명엔스퀘어)',
#   '율현주공후문',
#   '뜰천',
#   '원메이저푸르지오',
#   '모산초등학교',
#   '율하자이',
#   '율하2지구상가',
#   '율하2지구입구',
#   '장유모산마을',
#   '응달',
#   '응달마을',
#   '태정',
#   '용곡',
#   '수가마을회관',
#   '용곡',
#   '태정',
#   '응달마을',
#   '응달',
#   '장유모산마을',
#   '율하2지구입구',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저푸르지오',
#   '뜰천',
#   '율현주공후문',
#   '율하파출소(남명엔스퀘어)',
#   '서부문화센터',
#   '율하e-편한',
#   '율현주공',
#   '동원로얄듀크1차',
#   '농협수남지점',
#   '율하초등학교',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '화촌',
#   '죽림',
#   '한림풀에버',
#   '용산마을',
#   '용산',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '장유1동행정복지센터',
#   '코아상가',
#   '대동2단지',
#   '장유고등학교',
#   '장유석봉마을',
#   '장유초등학교',
#   '외덕',
#   '내덕중학교',
#   '무계e-편한',
#   '임시계류장'],
#  '24': ['임시계류장',
#   '무계e-편한',
#   '내덕중학교',
#   '외덕',
#   '장유초등학교',
#   '장유석봉마을',
#   '장유고등학교',
#   '월산중학교',
#   '주공7차아파트',
#   '월산3단지',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '용산',
#   '용산마을',
#   '한림풀에버',
#   '관동초등학교',
#   '중앙하이츠후문',
#   '중앙하이츠',
#   '율하e-편한',
#   '율현주공',
#   '동원로얄듀크1차',
#   '농협수남지점',
#   '율하초등학교',
#   '주공율곡마을정문',
#   '김해외국어고등학교',
#   '세영리첼정문',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '율하중심상가',
#   '동원로얄듀크1차',
#   '율현주공',
#   '율하e-편한',
#   '중앙하이츠',
#   '중앙하이츠후문',
#   '관동초등학교',
#   '한림풀에버',
#   '용산마을',
#   '용산',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '월산3단지',
#   '주공7단지',
#   '월산중학교',
#   '장유고등학교',
#   '장유석봉마을',
#   '장유초등학교',
#   '외덕',
#   '내덕중학교',
#   '무계e-편한',
#   '임시계류장'],
#  '25': ['롯데아울렛(기점)',
#   '롯데워터파크',
#   '롯데아울렛',
#   '김해농수산물유통센터',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '대동1단지',
#   '장유초등학교',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '장유출장소',
#   '부곡초등학교',
#   '주공7단지',
#   '월산중학교',
#   '장유고등학교',
#   '월산초등학교',
#   '주공아파트',
#   '젤미마을',
#   '젤미마을7단지',
#   '능동중학교',
#   '한림리츠빌',
#   '능동삼거리',
#   '장유도서관',
#   '계동',
#   '대청계곡',
#   '부영8차아파트',
#   '대청고등학교',
#   '대청초등학교',
#   '삼문2교',
#   '재영프라자사거리',
#   '메가병원',
#   '김해서부경찰서',
#   '갑오마을',
#   '부영8차앞',
#   '부영6차아파트',
#   '덕정사거리',
#   '덕정초등학교',
#   '공방마을',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠',
#   '율하e-편한',
#   '율현주공',
#   '동원로얄듀크1차',
#   '율하중심상가',
#   '중앙하이츠후문',
#   '관동초등학교',
#   '한림풀에버',
#   '용산마을',
#   '용산',
#   '농수산물유통센터입구',
#   '김해농수산물유통센터',
#   '롯데아울렛',
#   '롯데워터파크',
#   '롯데아울렛(기점)'],
#  '26': ['롯데아울렛(기점)',
#   '롯데워터파크',
#   '롯데아울렛',
#   '김해농수산물유통센터',
#   '용산',
#   '용산마을',
#   '한림풀에버',
#   '관동초등학교',
#   '중앙하이츠후문',
#   '율하중심상가',
#   '동원로얄듀크1차',
#   '율현주공',
#   '율하e-편한',
#   '중앙하이츠',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '세영리첼아파트',
#   '덕정초등학교',
#   '덕정사거리',
#   '부영9차',
#   '부영8차앞',
#   '부영8차아파트',
#   '대청계곡',
#   '계동',
#   '김해서부경찰서',
#   '메가병원',
#   '재영프라자사거리',
#   '삼문2교',
#   '대청초등학교',
#   '대청고등학교',
#   '갑오마을',
#   '장유도서관',
#   '능동삼거리',
#   '한림리츠빌',
#   '능동중학교',
#   '젤미마을4단지',
#   '젤미마을',
#   '부영11차아파트',
#   '월산초등학교',
#   '장유고등학교',
#   '월산중학교',
#   '주공7차아파트',
#   '부곡초등학교',
#   '장유출장소',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유초등학교',
#   '대동1단지',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '농수산물유통센터입구',
#   '김해농수산물유통센터',
#   '롯데아울렛',
#   '롯데워터파크',
#   '롯데아울렛(기점)'],
#  '3': ['풍유동차고지',
#   '풍유동차고지앞',
#   '농소교',
#   '한발매스테크',
#   '의생명센터',
#   '경부미곡처리장',
#   '명법2통',
#   '마찰',
#   '이동3통',
#   '이동2통',
#   '이동1통',
#   '화목1통',
#   '꽃샘공원',
#   '올래리골',
#   '화목2통 마을회관',
#   '칠산초등학교',
#   '칠산주민복지센터',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '수로왕릉역',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산주민복지센터',
#   '칠산초등학교',
#   '화목2통 마을회관',
#   '올래리골',
#   '꽃샘공원',
#   '화목1통',
#   '이동1통',
#   '이동2통',
#   '이동3통',
#   '마찰',
#   '명법2통',
#   '명법2통',
#   '부산은행주촌공단',
#   '중소기업비지니스센터',
#   '한발매스테크',
#   '농소교',
#   '풍유동차고지'],
#  '3-1': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산초등학교',
#   '칠산참외정보화마을',
#   '화목2통',
#   '바람개비공원',
#   '화목1통',
#   '이동1통',
#   '이동3통',
#   '김해농수산물유통센터',
#   '롯데아울렛',
#   '롯데워터파크',
#   '용산마을',
#   '한림풀에버',
#   '관동초등학교',
#   '중앙하이츠후문',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '율하초등학교',
#   '농협수남지점',
#   '동원로얄듀크1차',
#   '율현주공',
#   '율하e-편한',
#   '서부문화센터',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저힐스테이트',
#   '율산초등학교',
#   '율하시티프라디움',
#   '원메이저푸르지오',
#   '모산초등학교',
#   '율하자이',
#   '율하2지구상가',
#   '율하e-편한',
#   '율현주공',
#   '동원로얄듀크1차',
#   '농협수남지점',
#   '율하초등학교',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠후문',
#   '관동초등학교',
#   '한림풀에버',
#   '용산마을',
#   '롯데워터파크',
#   '롯데아울렛',
#   '김해농수산물유통센터',
#   '이동3통',
#   '이동1통',
#   '화목1통',
#   '바람개비공원',
#   '화목2통',
#   '칠산참외정보화마을',
#   '칠산초등학교',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '이마트 신세계백화점',
#   '외동차고지'],
#  '3-1A(막차)': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산초등학교',
#   '칠산참외정보화마을',
#   '화목2통',
#   '바람개비공원',
#   '화목1통',
#   '이동1통',
#   '이동3통',
#   '김해농수산물유통센터',
#   '롯데아울렛',
#   '롯데워터파크',
#   '용산마을',
#   '한림풀에버',
#   '관동초등학교',
#   '중앙하이츠후문',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '율하초등학교',
#   '농협수남지점',
#   '동원로얄듀크1차',
#   '율현주공',
#   '율하e-편한',
#   '서부문화센터',
#   '율하2지구상가',
#   '율하자이',
#   '원메이저힐스테이트',
#   '율산초등학교',
#   '율하시티프라디움'],
#  '30': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '주촌두산위브',
#   '동선마을',
#   '서선마을',
#   '주촌농협',
#   '연지마을',
#   '내선',
#   '원지',
#   '대리',
#   '석칠마을회관',
#   '석칠',
#   '국계',
#   '옥천',
#   '용곡',
#   '덕암아랫마을',
#   '덕암',
#   '옥천소류지',
#   '옥천소류지',
#   '덕암',
#   '덕암아랫마을',
#   '용곡',
#   '옥천',
#   '국계',
#   '석칠',
#   '석칠마을회관',
#   '대리',
#   '원지',
#   '내선',
#   '연지마을',
#   '주촌농협',
#   '서선마을',
#   '동선마을',
#   '주촌두산위브',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '30-1': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '주촌두산위브',
#   '동선마을',
#   '내선마을입구',
#   '내선',
#   '내연마을회관',
#   '옥천마을회관',
#   '덕암산업단지',
#   '옥천소류지',
#   '덕암',
#   '덕암아랫마을',
#   '용곡',
#   '옥천',
#   '국계',
#   '석칠',
#   '석칠마을회관',
#   '대리',
#   '원지',
#   '내선',
#   '내선마을입구',
#   '동선마을',
#   '주촌두산위브',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '30-1A(막차)': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '건강생활지원센터',
#   '주촌두산위브',
#   '동선마을',
#   '내선마을입구',
#   '내선',
#   '내연마을회관',
#   '옥천마을회관',
#   '덕암산업단지',
#   '점골마을',
#   '점골못',
#   '점골마을',
#   '옥천소류지',
#   '덕암',
#   '용곡',
#   '옥천',
#   '국계',
#   '석칠',
#   '석칠마을회관',
#   '대리',
#   '원지',
#   '내선',
#   '내선마을입구',
#   '동선마을',
#   '주촌두산위브',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '300': ['외동차고지',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '쇠내마을',
#   '옥천마을회관',
#   '병동농공단지입구',
#   '어병마을',
#   '서원병동마트',
#   '빙그레',
#   '진영역',
#   '설창',
#   '본산2로',
#   '금봉마을입구',
#   '봉하삼거리',
#   '봉하입구',
#   '봉하',
#   '봉하입구',
#   '봉하삼거리',
#   '금봉마을입구',
#   '본산농공단지입구',
#   '본산',
#   '용화사',
#   '본산공단입구',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '서원병동마트',
#   '어병마을',
#   '병동농공단지입구',
#   '옥천마을회관',
#   '쇠내마을',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '300A': ['외동차고지',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '쇠내마을',
#   '옥천마을회관',
#   '병동농공단지입구',
#   '서원병동마트',
#   '빙그레',
#   '진영역',
#   '설창',
#   '본산2로',
#   '금봉마을입구',
#   '봉하삼거리',
#   '본산농공단지입구',
#   '본산',
#   '용화사',
#   '본산공단입구',
#   '설창',
#   '진영역(김해행)',
#   '빙그레',
#   '신기',
#   '서원병동마트',
#   '병동농공단지입구',
#   '옥천마을회관',
#   '쇠내마을',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '31': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '농소교',
#   '한발매스테크',
#   '의생명센터',
#   '금광테크',
#   '신답마을',
#   '유넥스',
#   '서진중공업',
#   '유진금속',
#   '대양정기',
#   '영창테크',
#   '공단소공원',
#   '경남은행',
#   '부산은행주촌공단',
#   '한발매스테크',
#   '농소교',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '31A': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '전산마을',
#   '활천46통(수영)',
#   '전산마을',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '35': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '농소1교',
#   '농소',
#   '신답',
#   '망덕',
#   '신기',
#   '자현',
#   '부경축산',
#   '후포',
#   '가곡',
#   '신전',
#   '양동',
#   '신전',
#   '가곡',
#   '후포',
#   '부경축산',
#   '자현',
#   '신기',
#   '망덕',
#   '신답',
#   '농소',
#   '농소1교',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '이마트 신세계백화점',
#   '외동차고지'],
#  '35A': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '농소1교',
#   '농소',
#   '신답',
#   '망덕',
#   '신기',
#   '자현',
#   '부경축산',
#   '후포',
#   '가곡',
#   '신전',
#   '양동',
#   '신전',
#   '가곡',
#   '후포',
#   '부경축산',
#   '자현',
#   '신기',
#   '망덕',
#   '신답',
#   '농소',
#   '농소1교',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '무접',
#   '외동차고지(종점)'],
#  '3A': ['풍유동차고지',
#   '풍유동차고지앞',
#   '농소교',
#   '한발매스테크',
#   '의생명센터',
#   '경부미곡처리장',
#   '명법2통',
#   '마찰',
#   '이동3통',
#   '이동2통',
#   '이동1통',
#   '화목1통',
#   '꽃샘공원',
#   '올래리골',
#   '화목2통 마을회관',
#   '칠산초등학교',
#   '칠산주민복지센터',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '수로왕릉역',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산주민복지센터',
#   '칠산초등학교',
#   '화목2통 마을회관',
#   '올래리골',
#   '꽃샘공원',
#   '화목1통',
#   '이동1통',
#   '이동2통',
#   '이동3통',
#   '마찰',
#   '명법2통',
#   '명법2통',
#   '부산은행주촌공단',
#   '경남은행',
#   '주촌1소공원',
#   '스맥',
#   '스맥',
#   '주촌1소공원',
#   '경남은행',
#   '중소기업비지니스센터',
#   '한발매스테크',
#   '농소교',
#   '풍유동차고지'],
#  '3B': ['풍유동차고지',
#   '풍유동차고지앞',
#   '농소교',
#   '한발매스테크',
#   '의생명센터',
#   '경남은행',
#   '주촌1소공원',
#   '스맥',
#   '스맥',
#   '주촌1소공원',
#   '경남은행',
#   '경부미곡처리장',
#   '명법2통',
#   '마찰',
#   '이동3통',
#   '이동2통',
#   '이동1통',
#   '화목1통',
#   '꽃샘공원',
#   '올래리골',
#   '화목2통 마을회관',
#   '칠산초등학교',
#   '칠산주민복지센터',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '수로왕릉역',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산주민복지센터',
#   '칠산초등학교',
#   '화목2통 마을회관',
#   '올래리골',
#   '꽃샘공원',
#   '화목1통',
#   '이동1통',
#   '이동2통',
#   '이동3통',
#   '마찰',
#   '명법2통',
#   '명법2통',
#   '부산은행주촌공단',
#   '중소기업비지니스센터',
#   '한발매스테크',
#   '농소교',
#   '풍유동차고지'],
#  '4': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '무접',
#   '김해보건소',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내역',
#   '양장골',
#   '불암동행정복지센터',
#   '강변장어타운',
#   '중사도',
#   '시만교',
#   '시만',
#   '식만교',
#   '식만',
#   '옥매실황토방',
#   '용등',
#   '가락파출소',
#   '죽림삼거리',
#   '부산소프트웨어마이스터고교',
#   '봉림양수장',
#   '부산소프트웨어마이스터고교',
#   '죽림삼거리',
#   '가락동행정복지센터',
#   '용등',
#   '옥매실황토방',
#   '식만',
#   '식만교',
#   '시만',
#   '시만교',
#   '중사도',
#   '강변장어타운',
#   '불암동행정복지센터',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '경남은행',
#   '김해대학역',
#   '초선대',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '44': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산주민복지센터',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '시례',
#   '하곤법새터',
#   '하곤법',
#   '다곡',
#   '관곡마을',
#   '의전',
#   '등리',
#   '죽곡',
#   '외촌',
#   '세일아파트',
#   '유목공단',
#   '유목마을',
#   '용담마을',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영단감농협',
#   '진영중학교',
#   '금병초등학교',
#   '중흥S클래스',
#   '진영자이',
#   '진영중앙초등학교',
#   '진영이진캐스빌',
#   '중흥에코시티',
#   '진영공설운동장',
#   '진영공설운동장',
#   '진영공설운동장',
#   '중흥에코시티',
#   '진영이진캐스빌',
#   '진영중앙초등학교',
#   '진영자이',
#   '중흥S클래스',
#   '금병초등학교',
#   '진영중학교',
#   '진영단감농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '용담마을',
#   '유목마을',
#   '유목공단',
#   '세일아파트',
#   '외촌',
#   '죽곡',
#   '등리',
#   '의전',
#   '관곡마을',
#   '다곡',
#   '하곤법',
#   '하곤법새터',
#   '시례',
#   '진례농협(클레이아크)',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '칠산주민복지센터',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '이마트 신세계백화점',
#   '외동차고지'],
#  '44A': ['외동차고지',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '칠산주민복지센터',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '장유우체국',
#   '장유1동행정복지센터',
#   '코아상가',
#   '부영2차아파트',
#   '갑을장유병원',
#   '부영13차아파트',
#   '부곡',
#   '냉정사터',
#   '냉정회관',
#   '윗냉정',
#   '냉정마을',
#   '산본',
#   '신월마을',
#   '화전마을',
#   '신안',
#   '초전',
#   '평지마을입구',
#   '산월',
#   '진례파출소',
#   '진례농협',
#   '클레이아크김해미술관',
#   '시례',
#   '하곤법새터',
#   '하곤법',
#   '다곡',
#   '관곡마을',
#   '의전',
#   '등리',
#   '죽곡',
#   '외촌',
#   '세일아파트',
#   '농공단지입구',
#   '공단사거리',
#   '유목마을',
#   '용담마을',
#   '신용삼거리',
#   '신용마을',
#   '제암요양병원',
#   '용전마을',
#   '기영아파트',
#   '진영협성휴포레',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영단감농협',
#   '진영중학교',
#   '금병초등학교',
#   '중흥S클래스',
#   '진영자이',
#   '진영중앙초등학교',
#   '진영이진캐스빌',
#   '중흥에코시티',
#   '진영공설운동장',
#   '진영공설운동장',
#   '진영공설운동장',
#   '중흥에코시티',
#   '진영이진캐스빌',
#   '진영중앙초등학교',
#   '진영자이',
#   '중흥S클래스',
#   '금병초등학교',
#   '진영중학교',
#   '진영단감농협',
#   '진영시외주차장',
#   '제일고등학교',
#   '진영협성휴포레',
#   '기영아파트',
#   '용전마을',
#   '제암요양병원',
#   '신용마을',
#   '신용삼거리',
#   '용담마을',
#   '유목마을',
#   '공단사거리',
#   '농공단지입구',
#   '세일아파트',
#   '외촌',
#   '죽곡',
#   '등리',
#   '의전',
#   '관곡마을',
#   '다곡',
#   '하곤법',
#   '하곤법새터',
#   '시례',
#   '진례농협(클레이아크)',
#   '진례파출소',
#   '산월',
#   '평지마을입구',
#   '초전',
#   '신안',
#   '화전마을',
#   '신월마을',
#   '산본',
#   '냉정마을',
#   '윗냉정',
#   '냉정회관',
#   '냉정사터',
#   '부곡',
#   '부영13차아파트',
#   '갑을장유병원',
#   '부영2차아파트',
#   '코아상가',
#   '장유1동행정복지센터',
#   '장유우체국',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '칠산주민복지센터',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '이마트 신세계백화점',
#   '외동차고지'],
#  '4A': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '무접',
#   '김해보건소',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내역',
#   '양장골',
#   '불암동행정복지센터',
#   '강변장어타운',
#   '중사도',
#   '시만교',
#   '시만',
#   '식만교',
#   '식만',
#   '옥매실황토방',
#   '용등',
#   '가락파출소',
#   '죽림삼거리',
#   '부산소프트웨어마이스터고교',
#   '봉림양수장',
#   '렛츠런파크관람대',
#   '부산소프트웨어마이스터고교',
#   '죽림삼거리',
#   '가락동행정복지센터',
#   '용등',
#   '옥매실황토방',
#   '식만',
#   '식만교',
#   '시만',
#   '시만교',
#   '중사도',
#   '강변장어타운',
#   '불암동행정복지센터',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '경남은행',
#   '김해대학역',
#   '초선대',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '5-1': ['풍유동차고지',
#   '풍유동차고지앞',
#   '느타리공원',
#   '흥동3통',
#   '청호아트빌',
#   '대법륜사',
#   '일동한신아파트',
#   '외동사거리',
#   '외동축협',
#   '외동초등학교',
#   '신주공아파트',
#   '한국2차아파트',
#   '오복당서점',
#   '내외동행정복지센터',
#   '김해생명과학고실습장',
#   '내외문화의집',
#   '서김해새마을금고',
#   '내동사거리',
#   '대우아파트',
#   '연지우체국',
#   '홈플러스',
#   '김해문화의전당',
#   '광남백조아파트',
#   '구산동우체국',
#   '구산중학교',
#   '이진캐스빌',
#   '일동미라주',
#   '노인복지회관',
#   '삼계푸르지오2차',
#   '매정공원',
#   '시민체육공원',
#   '김해장애인복지관',
#   '분성고등학교',
#   '현대아파트',
#   '가야대역',
#   '삼계푸르지오1차',
#   '감분마을',
#   '대우이안아파트',
#   '가야대역',
#   '현대아파트',
#   '분성고등학교',
#   '김해장애인복지관',
#   '시민체육공원',
#   '매정공원',
#   '삼계푸르지오2차',
#   '노인복지회관',
#   '일동미라주',
#   '이진캐스빌',
#   '구산중학교',
#   '구산동우체국',
#   '광남백조아파트',
#   '김해문화의전당',
#   '휴앤락',
#   '대우아파트',
#   '내동사거리',
#   '서김해새마을금고',
#   '김해생명과학고실습장',
#   '내외동행정복지센터',
#   '오복당서점',
#   '대동아파트',
#   '외동초등학교',
#   '외동축협',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유동차고지'],
#  '56': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '금강병원',
#   '중앙지구대',
#   '신한은행',
#   '농협김해시지부',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '박물관역',
#   '문화의전당 정문',
#   '북부동원아파트',
#   '돋들이마을',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분',
#   '망천2구',
#   '망천1구',
#   '신천',
#   '명동정수장',
#   '금음',
#   '인현',
#   '명동',
#   '두례',
#   '낙산',
#   '화포천습지생태공원',
#   '어은마을',
#   '청원아파트',
#   '한림면행정복지센터',
#   '한림정역',
#   '한림초등학교',
#   '대항',
#   '진말입구',
#   '큰동뫼',
#   '시호1구',
#   '시호2구',
#   '시산양수장',
#   '술뫼파크골프장',
#   '윗가동',
#   '가동',
#   '가산',
#   '신전',
#   '신전마을',
#   '진영맑은물순환센터',
#   '주호교',
#   '주호마을회관',
#   '주호',
#   '진영휴먼빌',
#   '금병초등학교',
#   '부평',
#   '센텀큐브',
#   '진영LH6단지',
#   '진영휴먼시아',
#   '진영단감농협',
#   '진영시외주차장',
#   '진영시외주차장',
#   '진영단감농협',
#   '진영휴먼시아',
#   '진영LH6단지',
#   '센텀큐브',
#   '부평',
#   '금병초등학교',
#   '진영휴먼빌',
#   '주호',
#   '주호마을회관',
#   '주호교',
#   '진영맑은물순환센터',
#   '신전마을',
#   '신전',
#   '가산마을',
#   '가동마을',
#   '윗가동',
#   '술뫼파크골프장',
#   '시산양수장',
#   '시호2구',
#   '시호1구',
#   '큰동뫼',
#   '진말입구',
#   '대항',
#   '한림초등학교',
#   '한림정역',
#   '한림면행정복지센터',
#   '청원아파트',
#   '어은마을',
#   '화포천습지생태공원',
#   '낙산',
#   '두례',
#   '명동',
#   '인현',
#   '금음',
#   '신천',
#   '망천1구',
#   '망천2구',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '돋들이마을',
#   '북부동원아파트',
#   '문화의전당 정문',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '57': ['진영시외주차장',
#   '진영단감농협',
#   '진영중학교',
#   '금병초등학교',
#   '진영휴먼빌',
#   '주호',
#   '용성',
#   '본산',
#   '봉하입구',
#   '봉하',
#   '아랫대현',
#   '대현',
#   '장방리',
#   '장방입구',
#   '진말',
#   '진말입구',
#   '대항',
#   '한림초등학교',
#   '한림정역',
#   '부평',
#   '내오서',
#   '외오서',
#   '금곡마을',
#   '정촌마을',
#   '모정',
#   '시전',
#   '부평',
#   '한림정역',
#   '한림초등학교',
#   '대항',
#   '진말입구',
#   '진말',
#   '장방입구',
#   '장방리',
#   '대현',
#   '아랫대현',
#   '봉하',
#   '봉하입구',
#   '봉하삼거리',
#   '본산',
#   '용성',
#   '주호',
#   '진영휴먼빌',
#   '금병초등학교',
#   '진영중학교',
#   '진영단감농협',
#   '진영시외주차장'],
#  '57A': ['진영시외주차장',
#   '진영단감농협',
#   '진영중학교',
#   '금병초등학교',
#   '진영휴먼빌',
#   '주호',
#   '용성',
#   '본산',
#   '봉하입구',
#   '봉하',
#   '아랫대현',
#   '대현',
#   '장방리',
#   '장방입구',
#   '진말',
#   '진말입구',
#   '대항',
#   '한림초등학교',
#   '한림정역',
#   '모정',
#   '시전',
#   '부평',
#   '한림정역',
#   '한림초등학교',
#   '대항',
#   '진말입구',
#   '진말',
#   '장방입구',
#   '장방리',
#   '대현',
#   '아랫대현',
#   '봉하',
#   '봉하입구',
#   '봉하삼거리',
#   '본산',
#   '용성',
#   '주호',
#   '진영휴먼빌',
#   '금병초등학교',
#   '진영중학교',
#   '진영단감농협',
#   '진영시외주차장'],
#  '58': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '학생체육관(연지공원)',
#   '법원등기소입구',
#   '내동사거리',
#   '서김해새마을금고',
#   '내외문화의집',
#   '김해생명과학고',
#   '외동축협',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '용산',
#   '용산마을',
#   '유적체육공원',
#   '문화마을',
#   '중앙하이츠',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '세영리첼아파트',
#   '덕정초등학교',
#   '관동중학교',
#   '신안마을',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
#   '남산고등학교',
#   '대방동종점',
#   '성주프리빌리지아파트',
#   '대방그린빌아파트',
#   '대암고교',
#   '안남초등학교',
#   '대방대동아파트',
#   '사파동주민센터',
#   '성원3차아파트.노인종합복지관',
#   '사파동성아파트',
#   '사파동',
#   '창원축구센터.법원',
#   '검찰청',
#   '창원시립테니스장입구',
#   '토월공원',
#   '경남도청',
#   '도청사거리',
#   '성심유치원',
#   '창원대삼거리',
#   '우영프라자',
#   '창원대학교입구',
#   '창원대학교종점',
#   '창원대학교입구',
#   '우영프라자',
#   '사림동농협',
#   '사격장입구',
#   '경남대표도서관입구',
#   '장애인복지회관',
#   '봉림중학교',
#   '봉곡상가입구',
#   '까치아파트입구',
#   '지귀상가',
#   '유목교',
#   '농협하나로클럽',
#   '농업기술센터',
#   '파티마병원',
#   '파티마병원',
#   '종합터미널',
#   '창원기계공구상가',
#   '자동차검사장',
#   '공단회관',
#   '삼동',
#   '충혼탑',
#   '창원문성대학교',
#   '창원종합운동장',
#   '만남의광장',
#   '트리비앙아파트.한국폴리텍대학',
#   '중앙고등학교',
#   '창원시청.한서병원',
#   '수협경남금융본부',
#   '상남시장',
#   '토월대동아파트후문',
#   '웅남초등학교',
#   '토월대동아파트',
#   '토월성원아파트',
#   '상남도서관',
#   '더샵센트럴파크2단지',
#   '더샵센트럴파크1단지',
#   '남산초등학교',
#   '남산고등학교',
#   '남산중학교',
#   '남산버스정류소',
#   '남산아파트',
#   '성산구청(성주동마을도서관)',
#   '한국지엠/창원경상대학병원',
#   '한화테크윈 제2사업장',
#   '불모산',
#   '신안마을',
#   '관동중학교',
#   '덕정초등학교',
#   '공방마을',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠',
#   '문화마을',
#   '유적체육공원',
#   '용산마을',
#   '용산',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '외동사거리',
#   '외동축협',
#   '김해생명과학고',
#   '내외문화의집',
#   '서김해새마을금고',
#   '내동사거리',
#   '법원등기소입구',
#   '학생체육관(연지공원)',
#   '김해문화의전당',
#   '백조아파트후문',
#   '구산로타리',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '삼계푸르지오2차',
#   '장신대역',
#   '북부동행정복지센터',
#   '가야대역',
#   '삼계푸르지오1차',
#   '감분마을',
#   '신명마을',
#   '공원묘지입구',
#   '삼계차고지'],
#  '58-1': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '청호아트빌',
#   '흥동3통',
#   '흥동1통',
#   '흥동2통',
#   '흥동4통',
#   '봉황초등학교',
#   '동아그린앞',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '김해여고',
#   '청소년문화의집',
#   '광남백조아파트',
#   '구산동우체국',
#   '구산중학교',
#   '북부동원아파트',
#   '돋들이마을',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분',
#   '망천2구',
#   '망천1구',
#   '신천',
#   '명동정수장',
#   '금음',
#   '인현',
#   '명동',
#   '두례',
#   '낙산',
#   '화포천습지생태공원',
#   '어은마을',
#   '청원아파트',
#   '한림면행정복지센터',
#   '한림정역',
#   '부평',
#   '시전',
#   '모정',
#   '시전',
#   '부평',
#   '한림정역',
#   '한림면행정복지센터',
#   '청원아파트',
#   '어은마을',
#   '화포천습지생태공원',
#   '낙산',
#   '두례',
#   '명동',
#   '인현',
#   '금음',
#   '신천',
#   '망천1구',
#   '망천2구',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '돋들이마을',
#   '구산중학교',
#   '구산동우체국',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '흥동4통',
#   '흥동2통',
#   '흥동1통',
#   '흥동3통',
#   '느타리공원',
#   '풍유동차고지'],
#  '58A': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '학생체육관(연지공원)',
#   '법원등기소입구',
#   '내동사거리',
#   '서김해새마을금고',
#   '내외문화의집',
#   '김해생명과학고',
#   '외동축협',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '용산',
#   '용산마을',
#   '유적체육공원',
#   '문화마을',
#   '중앙하이츠',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '세영리첼아파트',
#   '덕정공원',
#   '부영8차앞',
#   '갑오마을',
#   '계동',
#   '대청계곡',
#   '계동초등학교',
#   '덕정사거리',
#   '관동중학교',
#   '신안마을',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
#   '남산고등학교',
#   '대방동종점',
#   '성주프리빌리지아파트',
#   '대방그린빌아파트',
#   '대암고교',
#   '안남초등학교',
#   '대방대동아파트',
#   '사파동주민센터',
#   '성원3차아파트.노인종합복지관',
#   '사파동성아파트',
#   '사파동',
#   '창원축구센터.법원',
#   '검찰청',
#   '창원시립테니스장입구',
#   '토월공원',
#   '경남도청',
#   '도청사거리',
#   '성심유치원',
#   '창원대삼거리',
#   '우영프라자',
#   '창원대학교입구',
#   '창원대학교종점',
#   '창원대학교입구',
#   '우영프라자',
#   '사림동농협',
#   '사격장입구',
#   '경남대표도서관입구',
#   '장애인복지회관',
#   '봉림중학교',
#   '봉곡상가입구',
#   '까치아파트입구',
#   '지귀상가',
#   '유목교',
#   '농협하나로클럽',
#   '농업기술센터',
#   '파티마병원',
#   '파티마병원',
#   '종합터미널',
#   '창원기계공구상가',
#   '자동차검사장',
#   '공단회관',
#   '삼동',
#   '충혼탑',
#   '창원문성대학교',
#   '창원종합운동장',
#   '만남의광장',
#   '트리비앙아파트.한국폴리텍대학',
#   '중앙고등학교',
#   '창원시청.한서병원',
#   '수협경남금융본부',
#   '상남시장',
#   '토월대동아파트후문',
#   '웅남초등학교',
#   '토월대동아파트',
#   '토월성원아파트',
#   '상남도서관',
#   '더샵센트럴파크2단지',
#   '더샵센트럴파크1단지',
#   '남산초등학교',
#   '남산고등학교',
#   '남산중학교',
#   '남산버스정류소',
#   '남산아파트',
#   '성산구청(성주동마을도서관)',
#   '한국지엠/창원경상대학병원',
#   '한화테크윈 제2사업장',
#   '불모산',
#   '신안마을',
#   '관동중학교',
#   '덕정초등학교',
#   '공방마을',
#   '세영리첼아파트',
#   '장유3동행정복지센터',
#   '주공율곡마을',
#   '율상푸르지오3단지',
#   '율하푸르지오4단지',
#   '모아미래도6단지',
#   '중앙하이츠',
#   '문화마을',
#   '유적체육공원',
#   '용산마을',
#   '용산',
#   '신문',
#   '장유중학교',
#   '범동포',
#   '무계교',
#   '장유농협',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '외동사거리',
#   '외동축협',
#   '김해생명과학고',
#   '내외문화의집',
#   '서김해새마을금고',
#   '내동사거리',
#   '법원등기소입구',
#   '학생체육관(연지공원)',
#   '김해문화의전당',
#   '백조아파트후문',
#   '구산로타리',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '삼계푸르지오2차',
#   '장신대역',
#   '북부동행정복지센터',
#   '가야대역',
#   '삼계푸르지오1차',
#   '감분마을',
#   '신명마을',
#   '공원묘지입구',
#   '삼계차고지'],
#  '59': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '학생체육관(연지공원)',
#   '법원등기소입구',
#   '내동사거리',
#   '서김해새마을금고',
#   '내외문화의집',
#   '김해생명과학고',
#   '외동축협',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '장유농협',
#   '무계교',
#   '하봉마을',
#   '장유중학교',
#   '신문',
#   '용산',
#   '용산마을',
#   '유적체육공원',
#   '문화마을',
#   '중앙하이츠',
#   '모아미래도6단지',
#   '율하푸르지오4단지',
#   '율상푸르지오3단지',
#   '주공율곡마을',
#   '장유3동행정복지센터',
#   '세영리첼아파트',
#   '덕정공원',
#   '부영8차앞',
#   '갑오마을',
#   '계동',
#   '도청골',
#   '대청계곡길',
#   '대청계곡입구',
#   '윗상점',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
# ...
#   '감분마을',
#   '신명마을',
#   '삼계정수장',
#   '천리교앞',
#   '예비군훈련장',
#   '안금마을입구',
#   '흰돌금식기도원',
#   '광재',
#   '상소락',
#   '소락마을',
#   '남성정밀',
#   '상동면행정복지센터',
#   '봉암입구',
#   '청사초롱',
#   '동척골',
#   '포산마을구판장',
#   '상동매리농협',
#   '아랫매리',
#   '매리',
#   '윗매리',
#   '고바우',
#   '고바우',
#   '윗매리',
#   '매리',
#   '아랫매리',
#   '상동매리농협',
#   '포산마을구판장',
#   '동척골',
#   '청사초롱',
#   '봉암입구',
#   '상동면행정복지센터',
#   '남성정밀',
#   '소락마을',
#   '상소락',
#   '광재',
#   '흰돌금식기도원',
#   '안금마을입구',
#   '예비군훈련장',
#   '천리교앞',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '농협김해시지부',
#   '국민은행',
#   '신한은행',
#   '중앙지구대',
#   '금강병원',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '동아그린아파트',
#   '봉황초등학교',
#   '칠산서부동행정복지센터',
#   '느타리공원',
#   '풍유동차고지'],
#  '73': ['여차',
#   '학운동',
#   '백학',
#   '백운동',
#   '용산초등학교',
#   '용산',
#   '감로',
#   '신곡',
#   '화현',
#   '아랫화현',
#   '매리취수장',
#   '고바우',
#   '윗매리',
#   '매리',
#   '아랫매리',
#   '상동매리농협',
#   '소감입구',
#   '고암',
#   '고암2반',
#   '고암3반',
#   '신촌',
#   '신암',
#   '덕산',
#   '월촌2교',
#   '월촌나루터',
#   '월촌',
#   '평촌',
#   '감천입구',
#   '하사',
#   '조눌',
#   '신동마을',
#   '신동2구',
#   '신동',
#   '안막2구',
#   '안막3구',
#   '대저수문',
#   '당리마을회관',
#   '당리마을입구',
#   '수문할매집',
#   '강서고.부산혜원학교',
#   '대저동',
#   '강서구청역',
#   '구포삼거리',
#   '북구청',
#   '한중병원',
#   '구포삼거리',
#   '구포역',
#   '구포시장종점',
#   '구포역',
#   '강서고.부산혜원학교',
#   '수문할매집',
#   '당리마을입구',
#   '당리마을회관',
#   '대저수문',
#   '안막3구',
#   '안막2구',
#   '신동',
#   '신동2구',
#   '신동마을',
#   '조눌',
#   '하사',
#   '감천입구',
#   '평촌',
#   '월촌',
#   '월촌나루터',
#   '월촌2교',
#   '덕산삼거리',
#   '덕산',
#   '신암',
#   '신촌',
#   '고암3반',
#   '고암2반',
#   '고암',
#   '소감입구',
#   '상동매리농협',
#   '아랫매리',
#   '매리',
#   '윗매리',
#   '고바우',
#   '매리취수장',
#   '아랫화현',
#   '화현',
#   '신곡',
#   '감로',
#   '용산',
#   '용산초등학교',
#   '백운동',
#   '백학',
#   '학운동',
#   '여차'],
#  '8': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '감분마을',
#   '삼계푸르지오1차',
#   '삼계동원로얄듀크',
#   '가야대학교',
#   '현대가야아이파크',
#   '삼계축협',
#   '매정공원',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '구산로타리',
#   '백조아파트후문',
#   '김해문화의전당',
#   '학생체육관(연지공원)',
#   '법원등기소입구',
#   '내동사거리',
#   '대우아파트',
#   '삼성아파트',
#   '현대2차아파트',
#   '오복당서점',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '동광초등학교',
#   '활천고개',
#   '선거관리위원회',
#   '미소지움아파트',
#   'SK브로드밴드',
#   '자성공원',
#   '어방마을',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동육거리',
#   '못안마을',
#   '활천초등학교',
#   '지내역',
#   '양장골',
#   '불암역',
#   '대사리1구',
#   '대사역.대사리2구',
#   '국립농산물품질관리원',
#   '대사리3구',
#   '평강역',
#   '중리입구',
#   '강서복지회관.우편집중국',
#   '낙동중학교',
#   '수로다리',
#   '대저119안전센터',
#   '강서구청',
#   '강서구청역',
#   '북구청',
#   '구포삼거리',
#   '구포역',
#   '구포시장',
#   '덕천역',
#   '숙등역',
#   '구포전화국',
#   '남산정역',
#   '만덕성당',
#   '만덕역.만덕사거리',
#   '광혜병원(미남역)',
#   '동래역',
#   '롯데백화점동래점',
#   '동래역',
#   '동래럭키아파트',
#   '미남교차로(미남역)',
#   '화신아파트',
#   '만덕교차로(만덕역)',
#   '만덕성당',
#   '남산정역',
#   '구포전화국',
#   '숙등역',
#   '덕천역',
#   '구포시장',
#   '구포역',
#   '강서구청역',
#   '강서구청',
#   '대저119안전센터',
#   '수로다리',
#   '낙동중학교',
#   '강서복지회관.우편집중국',
#   '중리입구',
#   '부산교도소',
#   '평강역',
#   '대사리3구',
#   '국립농산물품질관리원',
#   '대사역.대사리2구',
#   '대사리1구',
#   '불암역',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '자성공원',
#   'SK브로드밴드',
#   '미소지움아파트',
#   '선거관리위원회',
#   '활천고개',
#   '동광초등학교',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '오복당서점',
#   '현대2차아파트',
#   '삼성아파트',
#   '내동사거리',
#   '법원등기소입구',
#   '학생체육관(연지공원)',
#   '김해문화의전당',
#   '백조아파트후문',
#   '구산로타리',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '매정공원',
#   '삼계축협',
#   '현대가야아이파크',
#   '가야대학교',
#   '두곡마을',
#   '삼계푸르지오1차',
#   '감분마을',
#   '신명마을',
#   '공원묘지입구',
#   '삼계차고지'],
#  '8-1': ['삼계기점',
#   '공원묘지입구',
#   '신명마을',
#   '대우이안아파트',
#   '가야대역',
#   '북부동행정복지센터',
#   '장신대역',
#   '삼계푸르지오2차',
#   '구지마을',
#   '매정마을',
#   '구산신주공아파트',
#   '광남백조아파트',
#   '청소년문화의집',
#   '김해여고',
#   '김해향교',
#   '롯데캐슬',
#   '한덕아파트',
#   '활천고개',
#   '약수터',
#   '어방동원아파트',
#   '대우유토피아후문',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동육거리',
#   '못안마을',
#   '활천초등학교',
#   '지내역',
#   '양장골',
#   '불암역',
#   '대사리1구',
#   '대사역.대사리2구',
#   '국립농산물품질관리원',
#   '대사리3구',
#   '평강역',
#   '대저역',
#   '체육공원역',
#   '구명역',
#   '구포초등학교',
#   '구포시장남문.반도유보라아파트',
#   '구포시장동문',
#   '덕천교차로',
#   '구포시장',
#   '구포역',
#   '강서구청역',
#   '강서구청',
#   '대저119안전센터',
#   '수로다리',
#   '낙동중학교',
#   '강서복지회관.우편집중국',
#   '중리입구',
#   '부산교도소',
#   '평강역',
#   '대사리3구',
#   '국립농산물품질관리원',
#   '대사역.대사리2구',
#   '대사리1구',
#   '불암역',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '대우유토피아후문',
#   '어방동원아파트',
#   '약수터',
#   '활천고개',
#   '한덕아파트',
#   '롯데캐슬',
#   '김해향교',
#   '김해여고',
#   '청소년문화의집',
#   '광남백조아파트',
#   '구산신주공아파트',
#   '매정마을',
#   '구지마을',
#   '삼계푸르지오2차',
#   '장신대역',
#   '북부동행정복지센터',
#   '가야대역',
#   '대우이안아파트',
#   '신명마을',
#   '공원묘지입구',
#   '삼계차고지'],
#  '82': ['외동차고지',
#   '김해보건소',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내역',
#   '양장골',
#   '불암장어마을',
#   '선암',
#   '수안',
#   '선만고개',
#   '주중',
#   '성안',
#   '장시마을',
#   '동광원',
#   '시례',
#   '시례마을',
#   '마산',
#   '초정',
#   '대동면행정복지센터',
#   '원지마을',
#   '마산입구',
#   '운하교',
#   '안막1구',
#   '대동농협',
#   '대동중학교',
#   '안막2구',
#   '신동',
#   '신동2구',
#   '신동마을',
#   '조눌',
#   '하사',
#   '감천입구',
#   '평촌',
#   '월촌',
#   '월촌나루터',
#   '월촌2교',
#   '덕산삼거리',
#   '덕산',
#   '신암',
#   '신촌',
#   '고암3반',
#   '고암2반',
#   '고암',
#   '소감입구',
#   '상동매리농협',
#   '소감입구',
#   '고암',
#   '고암2반',
#   '고암3반',
#   '신촌',
#   '신암',
#   '덕산',
#   '월촌2교',
#   '월촌나루터',
#   '월촌',
#   '평촌',
#   '감천입구',
#   '하사',
#   '조눌',
#   '신동마을',
#   '신동2구',
#   '신동',
#   '안막2구',
#   '대동중학교',
#   '대동농협',
#   '안막1구',
#   '운하교',
#   '마산입구',
#   '원지마을',
#   '대동면행정복지센터',
#   '초정',
#   '마산',
#   '시례마을',
#   '시례',
#   '동광원',
#   '장시마을',
#   '성안마을',
#   '주중',
#   '선만고개',
#   '수안',
#   '선암',
#   '불암장어마을',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '경남은행',
#   '김해대학역',
#   '초선대',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '외동차고지(종점)'],
#  '82A': ['외동차고지',
#   '김해보건소',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내역',
#   '양장골',
#   '불암장어마을',
#   '선암',
#   '수안',
#   '선만고개',
#   '주중',
#   '성안',
#   '장시마을',
#   '동광원',
#   '시례',
#   '시례마을',
#   '마산',
#   '초정',
#   '대동면행정복지센터',
#   '원지마을',
#   '원지',
#   '괴정',
#   '지나',
#   '괴정소류지',
#   '감천',
#   '대감초등학교',
#   '덕산',
#   '신암',
#   '신촌',
#   '고암3반',
#   '고암2반',
#   '고암',
#   '소감입구',
#   '상동매리농협',
#   '소감입구',
#   '고암',
#   '고암2반',
#   '고암3반',
#   '신촌',
#   '신암',
#   '덕산',
#   '대감초등학교',
#   '감천',
#   '괴정소류지',
#   '지나',
#   '괴정',
#   '원지',
#   '원지마을',
#   '대동면행정복지센터',
#   '초정',
#   '마산',
#   '시례마을',
#   '시례',
#   '동광원',
#   '장시마을',
#   '성안마을',
#   '주중',
#   '선만고개',
#   '수안',
#   '선암',
#   '불암장어마을',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '경남은행',
#   '김해대학역',
#   '초선대',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '외동차고지(종점)'],
#  '83': ['상동매리농협',
#   '소감입구',
#   '고암',
#   '고암2반',
#   '고암3반',
#   '신촌',
#   '신암',
#   '덕산',
#   '월촌2교',
#   '월촌나루터',
#   '월촌',
#   '평촌',
#   '감천입구',
#   '하사',
#   '조눌',
#   '신동마을',
#   '신동2구',
#   '신동',
#   '안막2구',
#   '안막3구',
#   '안막3구',
#   '안막2구',
#   '신동',
#   '신동2구',
#   '신동마을',
#   '조눌',
#   '하사',
#   '감천입구',
#   '평촌',
#   '월촌',
#   '월촌나루터',
#   '월촌2교',
#   '덕산삼거리',
#   '덕산',
#   '신암',
#   '신촌',
#   '고암3반',
#   '고암2반',
#   '고암',
#   '소감입구',
#   '상동매리농협'],
#  '9': ['풍유동차고지',
#   '풍유동차고지앞',
#   '풍유동',
#   '선천지구입구',
#   '센텀큐시티정문',
#   '센텀큐시티후문',
#   '선천중심상가',
#   '조만강',
#   '주촌서희',
#   '센텀두산위브',
#   '선천마을',
#   '선천산책로',
#   '주촌교차로',
#   '서선마을',
#   '동선마을',
#   '주촌두산위브',
#   '건강생활지원센터',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '신주공아파트',
#   '한국2차아파트',
#   '한국1차아파트',
#   '동일아파트',
#   '임호중학교',
#   '내외동행정복지센터',
#   '현대4차아파트',
#   '건영아파트',
#   '내동사거리',
#   '법원등기소입구',
#   '연지공원',
#   '북부동원아파트',
#   '돋들이마을',
#   '부영6차아파트',
#   '조은금강병원',
#   '동신아파트',
#   '감분마을',
#   '대우이안아파트',
#   '삼계동원로얄듀크',
#   '가야대학교',
#   '현대가야아이파크',
#   '삼계축협',
#   '삼계동부산은행',
#   '북부동행정복지센터',
#   '가야대역',
#   '대우이안아파트',
#   '감분마을',
#   '동신아파트',
#   '조은금강병원',
#   '부영6차아파트',
#   '돋들이마을',
#   '북부동원아파트',
#   '연지공원',
#   '법원등기소입구',
#   '내동사거리',
#   '건영아파트',
#   '현대4차아파트',
#   '내외동행정복지센터',
#   '임호초등학교',
#   '덕산아파트',
#   '대동아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '주촌두산위브',
#   '동선마을',
#   '서선마을',
#   '주촌교차로',
#   '선천산책로',
#   '선천마을',
#   '센텀두산위브',
#   '주촌서희',
#   '조만강',
#   '선천중심상가',
#   '센텀큐시티후문',
#   '센텀큐시티정문',
#   '선천지구입구',
#   '풍유동',
#   '풍유동차고지'],
#  '97': ['선암',
#   '선암',
#   '불암역',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '대우유토피아후문',
#   '어방동원아파트',
#   '약수터',
#   '활천고개',
#   '동광초등학교',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '대동1단지',
#   '장유초등학교',
#   '장유석봉마을',
#   '월산초등학교',
#   '주공아파트',
#   '장유스포츠센터',
#   '장유푸르지오8차',
#   '대청초등학교',
#   '대청고등학교',
#   '갑오마을',
#   '계동',
#   '대청계곡',
#   '계동초등학교',
#   '덕정사거리',
#   '관동중학교',
#   '신안마을',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
#   '남산고등학교',
#   '대방동종점',
#   '대방동성아파트',
#   '안남중학교',
#   '임마뉴엘교회',
#   '대방초등학교',
#   '대방덕산아파트',
#   '성원3차아파트.노인종합복지관',
#   '사파동성아파트',
#   '사파동',
#   '창원축구센터.법원',
#   '검찰청',
#   '창원시립테니스장입구',
#   '토월공원',
#   '경남도청',
#   '도청사거리',
#   '성심유치원',
#   '창원대삼거리',
#   '우영프라자',
#   '창원대학교입구',
#   '창원대학교종점',
#   '창원대학교입구',
#   '우영프라자',
#   '창원대삼거리',
#   '창원의집 입구',
#   '사림동',
#   '장애인복지회관입구',
#   '봉곡상가입구',
#   '까치아파트',
#   '럭키상가',
#   '운동장사거리',
#   '창원종합운동장',
#   '만남의광장',
#   '트리비앙아파트.한국폴리텍대학',
#   '중앙고등학교',
#   '창원시청.한서병원',
#   '은아아파트',
#   '시민생활체육관',
#   '대동백화점',
#   '토월성원아파트',
#   '상남도서관',
#   '더샵센트럴파크2단지',
#   '더샵센트럴파크1단지',
#   '여성회관창원관',
#   '성주초등학교',
#   '남산버스정류소',
#   '남산아파트',
#   '성산구청(성주동마을도서관)',
#   '한국지엠/창원경상대학병원',
#   '한화테크윈 제2사업장',
#   '불모산',
#   '신안마을',
#   '관동중학교',
#   '덕정사거리',
#   '계동초등학교',
#   '대청계곡',
#   '계동',
#   '갑오마을',
#   '대청고등학교',
#   '대청초등학교',
#   '장유푸르지오8차',
#   '장유스포츠센터',
#   '부영11차아파트',
#   '월산초등학교',
#   '장유석봉마을',
#   '장유초등학교',
#   '대동1단지',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '동광초등학교',
#   '활천고개',
#   '약수터',
#   '어방동원아파트',
#   '대우유토피아후문',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동육거리',
#   '못안마을',
#   '활천초등학교',
#   '지내역',
#   '불암장어마을',
#   '선암'],
#  '97-1': ['계동(종점)',
#   '갑오마을',
#   '장유도서관',
#   '능동삼거리',
#   '한림리츠빌',
#   '한림리츠빌',
#   '능동삼거리',
#   '장유도서관',
#   '계동',
#   '대청계곡',
#   '계동초등학교',
#   '덕정사거리',
#   '관동중학교',
#   '신안마을',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
#   '남산버스정류소',
#   '남산아파트',
#   '성산구청(성주동마을도서관)',
#   '한국지엠/창원경상대학병원',
#   '한화테크윈 제2사업장',
#   '불모산',
#   '신안마을',
#   '관동중학교',
#   '덕정사거리',
#   '계동초등학교',
#   '갑오마을'],
#  '98': ['선암',
#   '선암',
#   '불암역',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '지내동입구',
#   '활천초등학교',
#   '못안마을',
#   '안동육거리',
#   '한일여고',
#   '계내',
#   '한샘베스트빌라',
#   '신어중학교',
#   '동성아파트',
#   '삼방시장',
#   '화인아파트',
#   '영운초등학교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '대우유토피아후문',
#   '어방동원아파트',
#   '약수터',
#   '활천고개',
#   '동광초등학교',
#   '동상동',
#   '분성사거리',
#   '수로왕릉',
#   '김해도서관',
#   '김해보건소',
#   '한국1차아파트',
#   '한국2차아파트',
#   '중앙병원',
#   '한신아파트',
#   '일동한신아파트',
#   '대법륜사',
#   '풍유동',
#   '풍유2통',
#   '명법1통',
#   '명법2통',
#   '내덕',
#   '내덕서희',
#   '남명더라우',
#   '대동1단지',
#   '장유초등학교',
#   '장유석봉마을',
#   '월산초등학교',
#   '주공아파트',
#   '장유스포츠센터',
#   '장유푸르지오8차',
#   '대청초등학교',
#   '대청고등학교',
#   '갑오마을',
#   '계동',
#   '대청계곡',
#   '계동초등학교',
#   '덕정사거리',
#   '관동중학교',
#   '신안마을',
#   '삼정자내리마을',
#   '내리',
#   '창원경상대학병원',
#   '성산구청(성주동마을도서관)',
#   '남산공원환승센터',
#   '남산중학교',
#   '여성회관창원관',
#   '피오르빌아파트',
#   '남양초등학교',
#   '한림아파트',
#   '사파삼익아파트',
#   '대동백화점',
#   '시민생활체육관',
#   '은아아파트',
#   '창원시청',
#   '정우상가',
#   '중앙고등학교',
#   '트리비앙아파트.한국폴리텍대학',
#   '노블파크아파트',
#   '운동장사거리',
#   '럭키상가',
#   '까치아파트',
#   '대동그린코아',
#   '장애인복지회관입구',
#   '사림동',
#   '창원의집 입구',
#   '창원대삼거리',
#   '우영프라자',
#   '창원대학교입구',
#   '창원대학교종점',
#   '창원대학교입구',
#   '우영프라자',
#   '창원대삼거리',
#   '성심유치원',
#   '청룡길',
#   '도청사거리',
#   '경남도청',
#   '토월공원',
#   '창원시립테니스장입구',
#   '검찰청',
#   '창원축구센터.법원',
#   '사파동',
#   '사파동성아파트',
#   '남양동성아파트.노인종합복지관',
#   '남양성원2차아파트',
#   '남양개나리3차아파트',
#   '남양동주택',
#   '안남중학교',
#   '대방동종점',
#   '남산고등학교',
#   '남산중학교',
#   '남산버스정류소',
#   '남산아파트',
#   '성산구청(성주동마을도서관)',
#   '한국지엠/창원경상대학병원',
#   '한화테크윈 제2사업장',
#   '불모산',
#   '신안마을',
#   '관동중학교',
#   '덕정사거리',
#   '계동초등학교',
#   '대청계곡',
#   '계동',
#   '갑오마을',
#   '대청고등학교',
#   '대청초등학교',
#   '장유푸르지오8차',
#   '장유스포츠센터',
#   '부영11차아파트',
#   '월산초등학교',
#   '장유석봉마을',
#   '장유초등학교',
#   '대동1단지',
#   '남명더라우',
#   '내덕서희',
#   '내덕',
#   '명법2통',
#   '명법1통',
#   '풍유2통',
#   '풍유동',
#   '대법륜사',
#   '일동한신아파트',
#   '한신아파트',
#   '중앙병원',
#   '임호성당',
#   '조흥그린',
#   '무접마을',
#   '김해보건소',
#   '김해도서관',
#   '수로왕릉',
#   '분성사거리',
#   '동상동',
#   '동광초등학교',
#   '활천고개',
#   '약수터',
#   '어방동원아파트',
#   '대우유토피아후문',
#   '인제대학교',
#   '인제공원',
#   '삼방동장애인복지관',
#   '영운초등학교',
#   '화인아파트',
#   '삼방시장',
#   '동성아파트',
#   '신어중학교',
#   '계내',
#   '한일여고',
#   '안동육거리',
#   '못안마을',
#   '활천초등학교',
#   '지내역',
#   '불암장어마을',
#   '선암'],
#  '대동공영': ['풍유동차고지',
#   '풍유동차고지앞',
#   '느타리공원',
#   '칠산서부동행정복지센터',
#   '봉황초등학교',
#   '동아그린앞',
#   '무접',
#   '김해보건소',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해시청',
#   '복음병원입구',
#   '성모병원',
#   '인제대역',
#   '초선대',
#   '김해대학역',
#   '경남은행',
#   '지내역',
#   '양장골',
#   '불암장어마을',
#   '선암',
#   '수안',
#   '선만고개',
#   '주중',
#   '성안',
#   '장시마을',
#   '신안마을',
#   '마산',
#   '신안',
#   '예안교회',
#   '신정입구',
#   '신정',
#   '신정교',
#   '안막3구',
#   '대동중학교',
#   '대동농협',
#   '안막1구',
#   '운하교',
#   '마산입구',
#   '원지',
#   '괴정',
#   '지나',
#   '괴정소류지',
#   '감천',
#   '대감초등학교',
#   '덕산삼거리',
#   '덕산',
#   '대감초등학교',
#   '감천',
#   '괴정소류지',
#   '지나',
#   '괴정',
#   '원지',
#   '마산입구',
#   '운하교',
#   '안막1구',
#   '대동농협',
#   '대동중학교',
#   '안막3구',
#   '신정교',
#   '신정',
#   '신정입구',
#   '예안교회',
#   '신안',
#   '마산',
#   '신안마을',
#   '장시마을',
#   '성안마을',
#   '주중',
#   '선만고개',
#   '수안',
#   '선암',
#   '불암장어마을',
#   '양장골',
#   '지내역',
#   '지내동원아파트',
#   '경남은행',
#   '김해대학역',
#   '초선대',
#   '인제대역',
#   '성모병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '부원역',
#   '김해중부경찰서',
#   '봉황역',
#   '무접',
#   '동아그린아파트',
#   '봉황초등학교',
#   '칠산서부동행정복지센터',
#   '느타리공원',
#   '풍유동차고지'],
#  '도시형1': ['한림면행정복지센터',
#   '한림정역',
#   '내오서',
#   '외오서',
#   '오서안골',
#   '내오서경로회관',
#   '금곡마을회관',
#   '정촌마을',
#   '한림정역',
#   '한림면행정복지센터'],
#  '도시형2': ['인제대역',
#   '메가마트',
#   '활천46통(수영)',
#   '활천22통(전산)',
#   '부원14통(쇠내)',
#   '부원역',
#   '김해터미널(남문)',
#   '봉황초등학교',
#   '전하1통',
#   '농업기술센터',
#   '전하1통',
#   '흥동2통(평리)',
#   '봉황초등학교',
#   '봉황역',
#   '부원역',
#   '부원14통(쇠내)',
#   '활천22통(전산)',
#   '활천46통(수영)',
#   '메가마트',
#   '인제대역'],
#  '도시형3': ['어병마을',
#   '모업',
#   '소업마을',
#   '퇴은',
#   '삼미',
#   '신기마을',
#   '진영역',
#   '효동마을',
#   '아랫양지',
#   '윗양지',
#   '용전',
#   '제일고등학교',
#   '진영시외주차장',
#   '진영시외주차장',
#   '제일고등학교',
#   '용전',
#   '윗양지',
#   '아랫양지',
#   '효동마을',
#   '진영역(김해행)',
#   '신기마을',
#   '삼미',
#   '퇴은',
#   '소업마을',
#   '어병마을'],
#  '상동공영1': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '봉황역',
#   '김해중부경찰서',
#   '부원역',
#   '김해세무서',
#   '김해천주교회',
#   '동광초등학교',
#   '활천고개',
#   '약수터',
#   '어방동원아파트',
#   '대우유토피아후문',
#   '인제대학교',
#   '인제공원',
#   '삼방교',
#   '가야랜드입구',
#   '영운마을',
#   '윗안금마을입구',
#   '나전윗길찻집',
#   '묵방마을회관',
#   '묵방마을',
#   '신어공원입구',
#   '성화사',
#   '영진가든',
#   '상소락',
#   '소락경로당',
#   '소락공장단지',
#   '양돈단지입구',
#   '찜질방입구',
#   '장척마을',
#   '생수공장',
#   '내동골윗',
#   '장척계곡가든',
#   '상동야구장',
#   '상동면행정복지센터',
#   '봉암입구',
#   '청사초롱',
#   '동척골',
#   '포산마을구판장',
#   '상동매리농협',
#   '아랫매리',
#   '매리',
#   '윗매리',
#   '고바우',
#   '매리취수장',
#   '아랫화현',
#   '화현',
#   '신곡',
#   '감로',
#   '용산',
#   '용산초등학교',
#   '백운동',
#   '백학',
#   '학운동',
#   '여차',
#   '여차고개',
#   '여차고개삼거리',
#   '하나전',
#   '나전공단입구',
#   '안금마을입구',
#   '안금마을',
#   '나전윗길찻집',
#   '윗안금마을입구',
#   '영운마을',
#   '삼방교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '어방마을',
#   '어방2주공아파트',
#   '송림공원',
#   '삼성초등학교',
#   '활천동',
#   '복음병원',
#   '복음병원입구',
#   '김해시청',
#   '한솔병원',
#   '김해세무서',
#   '김해천주교회',
#   '동상동',
#   '김해향교',
#   '대성사거리',
#   '김해여중',
#   '김해교육지원청',
#   '이마트 신세계백화점',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)'],
#  '상동공영2': ['외동차고지(종점)',
#   '이마트 신세계백화점',
#   '김해터미널(정문)',
#   '무접',
#   '김해보건소',
#   '김해교육지원청',
#   '김해여중',
#   '대성사거리',
#   '김해향교',
#   '동상동',
#   '김해천주교회',
#   '김해세무서',
#   '김해시청',
#   '복음병원입구',
#   '복음병원',
#   '활천동',
#   '삼성초등학교',
#   '송림공원',
#   '어방2주공아파트',
#   '어방마을',
#   '인제대학교',
#   '인제공원',
#   '삼방교',
#   '가야랜드입구',
#   '영운마을',
#   '윗안금마을입구',
#   '나전윗길찻집',
#   '안금마을',
#   '안금마을입구',
#   '나전공단입구',
#   '하나전',
#   '여차고개삼거리',
#   '여차고개',
#   '여차',
#   '학운동',
#   '백학',
#   '백운동',
#   '용산초등학교',
#   '용산',
#   '감로',
#   '신곡',
#   '화현',
#   '아랫화현',
#   '매리취수장',
#   '고바우',
#   '윗매리',
#   '매리',
#   '아랫매리',
#   '상동매리농협',
#   '포산마을구판장',
#   '동척골',
#   '청사초롱',
#   '봉암입구',
#   '상동면행정복지센터',
#   '상동야구장',
#   '장척계곡가든',
#   '내동골윗',
#   '생수공장',
#   '장척마을',
#   '찜질방입구',
#   '양돈단지입구',
#   '소락공장단지',
#   '소락경로당',
#   '소락마을',
#   '우계',
#   '소락마을',
#   '영진가든',
#   '성화사',
#   '신어공원입구',
#   '윗묵방',
#   '묵방마을회관',
#   '나전윗길찻집',
#   '윗안금마을입구',
#   '영운마을',
#   '삼방교',
#   '삼방동장애인복지관',
#   '인제공원',
#   '인제대학교',
#   '대우유토피아',
#   '대우유토피아후문',
#   '어방동원아파트',
#   '약수터',
#   '활천고개',
#   '동광초등학교',
#   '김해천주교회',
#   '김해세무서',
#   '부원역',
#   '김해중부경찰서',
#   '김해터미널(남문)',
#   '무접',
#   '외동차고지(종점)']}

# %%
import pandas as pd

bus_routes_data = bus_routes

# 정류장 개수를 맞추기 위한 빈 값 추가
max_stops = max(len(stops) for stops in bus_routes_data.values())
for stops in bus_routes_data.values():
    while len(stops) < max_stops:
        stops.append(None)

# 데이터프레임 생성
bus_routes_df = pd.DataFrame(bus_routes_data)

# 결과 출력
print(bus_routes_df)
# Out:
#             1       1-1      10      100      11   11A       12          13  \
# 0        삼계기점      삼계기점     진영역   풍유동차고지      상룡    상룡  진영공설운동장       임시계류장
# 1      공원묘지입구    공원묘지입구      설창  풍유동차고지앞    용담마을  효동마을  진영공설운동장      무계e-편한
# 2        삼계서희      신명마을   신용삼거리      풍유동   신용삼거리  아랫양지     진영병원        장유농협
# 3    삼계동원로얄듀크      감분마을    신용마을    청호아트빌    신용마을   윗양지    삼성아파트       장유우체국
# 4       가야대학교  삼계푸르지오1차  제암요양병원     흥동3통  제암요양병원    용전       부곡  장유1동행정복지센터
# ..        ...       ...     ...      ...     ...   ...      ...         ...
# 180      None      None    None     None    None  None     None        None
# 181      None      None    None     None    None  None     None        None
# 182      None      None    None     None    None  None     None        None
# 183      None      None    None     None    None  None     None        None
# 184      None      None    None     None    None  None     None        None
#
#            14-1       14-1A  ...        9    97    97-1    98         대동공영  \
# 0     외동차고지(종점)   외동차고지(종점)  ...   풍유동차고지    선암  계동(종점)    선암       풍유동차고지
# 1    이마트 신세계백화점  이마트 신세계백화점  ...  풍유동차고지앞    선암    갑오마을    선암      풍유동차고지앞
# 2     김해터미널(정문)   김해터미널(정문)  ...      풍유동   불암역   장유도서관   불암역        느타리공원
# 3            무접          무접  ...   선천지구입구   양장골   능동삼거리   양장골  칠산서부동행정복지센터
# 4       한국1차아파트     한국1차아파트  ...  센텀큐시티정문   지내역   한림리츠빌   지내역       봉황초등학교
# ..          ...         ...  ...      ...   ...     ...   ...          ...
# 180        None        None  ...     None  None    None  None         None
# 181        None        None  ...     None  None    None  None         None
# 182        None        None  ...     None  None    None  None         None
# 183        None        None  ...     None  None    None  None         None
# 184        None        None  ...     None  None    None  None         None
#
#           도시형1       도시형2  도시형3       상동공영1       상동공영2
# 0    한림면행정복지센터       인제대역  어병마을   외동차고지(종점)   외동차고지(종점)
# 1         한림정역       메가마트    모업  이마트 신세계백화점  이마트 신세계백화점
# 2          내오서  활천46통(수영)  소업마을   김해터미널(정문)   김해터미널(정문)
# 3          외오서  활천22통(전산)    퇴은         봉황역          무접
# 4         오서안골  부원14통(쇠내)    삼미     김해중부경찰서       김해보건소
# ..         ...        ...   ...         ...         ...
# 180       None       None  None        None        None
# 181       None       None  None        None        None
# 182       None       None  None        None        None
# 183       None       None  None        None        None
# 184       None       None  None        None        None
#
# [185 rows x 90 columns]

# %%
bus_routes_df.to_csv('버스 번호별 노선2.csv')
